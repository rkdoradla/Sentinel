# %% [markdown]
# # Welcome to Modal notebooks!
#
# Write Python code and collaborate in real time. Your code runs in Modal's
# **serverless cloud**, and anyone in the same workspace can join.
#
# This notebook comes with some common Python libraries installed. Run
# cells with `Shift+Enter`.

# %%
# %uv pip install inspect-ai transformer-lens streamlit
# Out:
# Using Python 3.12.6 environment at: /usr/local
# Resolved 141 packages in 916ms
# ⠙ Preparing packages... (0/55)
# ⠙ Preparing packages... (0/55)
# ⠙ Preparing packages... (0/55)
# smmap      ------------------------------     0 B/23.73 KiB
# ⠙ Preparing packages... (0/55)
# smmap      ------------------------------ 14.88 KiB/23.73 KiB
# ⠙ Preparing packages... (0/55)
# semver     ------------------------------     0 B/17.49 KiB
# smmap      ------------------------------ 14.88 KiB/23.73 KiB
# ⠙ Preparing packages... (0/55)
# frozendict ------------------------------     0 B/15.88 KiB
# semver     ------------------------------     0 B/17.49 KiB
# smmap      ------------------------------ 14.88 KiB/23.73 KiB
# ⠙ Preparing packages... (0/55)
# jsonpatch  ------------------------------     0 B/12.60 KiB
# frozendict ------------------------------     0 B/15.88 KiB
# semver     ------------------------------     0 B/17.49 KiB
# smmap      ------------------------------ 14.88 KiB/23.73 KiB
# ⠙ Preparing packages... (0/55)
# cachetools ------------------------------     0 B/11.28 KiB
# jsonpatch  ------------------------------     0 B/12.60 KiB
# frozendict ------------------------------     0 B/15.88 KiB
# semver     ------------------------------     0 B/17.49 KiB
# smmap      ------------------------------ 14.88 KiB/23.73 KiB
# ⠙ Preparing packages... (0/55)
# jsonpointer ------------------------------     0 B/7.42 KiB
# cachetools ------------------------------     0 B/11.28 KiB
# jsonpatch  ------------------------------     0 B/12.60 KiB
# frozendict ------------------------------     0 B/15.88 KiB
# semver     ------------------------------     0 B/17.49 KiB
# smmap      ------------------------------ 14.88 KiB/23.73 KiB
# ⠙ Preparing packages... (0/55)
# jsonpointer ------------------------------     0 B/7.42 KiB
# cachetools ------------------------------     0 B/11.28 KiB
# jsonpatch  ------------------------------     0 B/12.60 KiB
# frozendict ------------------------------     0 B/15.88 KiB
# semver     ------------------------------     0 B/17.49 KiB
# smmap      ------------------------------ 14.88 KiB/23.73 KiB
# tenacity   ------------------------------ 14.88 KiB/27.59 KiB
# ⠙ Preparing packages... (0/55)
# jsonpointer ------------------------------     0 B/7.42 KiB
# cachetools ------------------------------     0 B/11.28 KiB
# jsonpatch  ------------------------------     0 B/12.60 KiB
# frozendict ------------------------------     0 B/15.88 KiB
# semver     ------------------------------     0 B/17.49 KiB
# smmap      ------------------------------ 14.88 KiB/23.73 KiB
# tenacity   ------------------------------ 14.88 KiB/27.59 KiB
# botocore   ------------------------------     0 B/13.40 MiB
# ⠙ Preparing packages... (0/55)
# jsonpointer ------------------------------     0 B/7.42 KiB
# jsonlines  ------------------------------     0 B/8.50 KiB
# cachetools ------------------------------     0 B/11.28 KiB
# jsonpatch  ------------------------------     0 B/12.60 KiB
# frozendict ------------------------------     0 B/15.88 KiB
# semver     ------------------------------     0 B/17.49 KiB
# smmap      ------------------------------ 14.88 KiB/23.73 KiB
# tenacity   ------------------------------ 14.88 KiB/27.59 KiB
# botocore   ------------------------------     0 B/13.40 MiB
# ⠙ Preparing packages... (0/55)
# jsonpointer ------------------------------     0 B/7.42 KiB
# jsonlines  ------------------------------     0 B/8.50 KiB
# cachetools ------------------------------     0 B/11.28 KiB
# jsonpatch  ------------------------------     0 B/12.60 KiB
# frozendict ------------------------------     0 B/15.88 KiB
# semver     ------------------------------     0 B/17.49 KiB
# smmap      ------------------------------ 14.88 KiB/23.73 KiB
# tenacity   ------------------------------ 14.88 KiB/27.59 KiB
# botocore   ------------------------------     0 B/13.40 MiB
# wandb      ------------------------------     0 B/21.79 MiB
# ⠙ Preparing packages... (0/55)
# jsonpointer ------------------------------     0 B/7.42 KiB
# jsonlines  ------------------------------     0 B/8.50 KiB
# cachetools ------------------------------     0 B/11.28 KiB
# jsonpatch  ------------------------------     0 B/12.60 KiB
# frozendict ------------------------------     0 B/15.88 KiB
# semver     ------------------------------     0 B/17.49 KiB
# smmap      ------------------------------ 14.88 KiB/23.73 KiB
# tenacity   ------------------------------ 14.88 KiB/27.59 KiB
# pydeck     ------------------------------     0 B/6.58 MiB
# botocore   ------------------------------     0 B/13.40 MiB
# wandb      ------------------------------     0 B/21.79 MiB
# ⠙ Preparing packages... (0/55)
# jsonpointer ------------------------------     0 B/7.42 KiB
# jsonlines  ------------------------------     0 B/8.50 KiB
# cachetools ------------------------------     0 B/11.28 KiB
# jsonpatch  ------------------------------     0 B/12.60 KiB
# frozendict ------------------------------     0 B/15.88 KiB
# semver     ------------------------------     0 B/17.49 KiB
# smmap      ------------------------------ 14.88 KiB/23.73 KiB
# tenacity   ------------------------------ 14.88 KiB/27.59 KiB
# pydeck     ------------------------------     0 B/6.58 MiB
# botocore   ------------------------------     0 B/13.40 MiB
# wandb      ------------------------------     0 B/21.79 MiB
# inspect-ai ------------------------------     0 B/32.96 MiB
# ⠙ Preparing packages... (0/55)
# jsonpointer ------------------------------     0 B/7.42 KiB
# jsonlines  ------------------------------     0 B/8.50 KiB
# cachetools ------------------------------     0 B/11.28 KiB
# jsonpatch  ------------------------------     0 B/12.60 KiB
# frozendict ------------------------------     0 B/15.88 KiB
# semver     ------------------------------     0 B/17.49 KiB
# smmap      ------------------------------ 14.88 KiB/23.73 KiB
# tenacity   ------------------------------ 14.88 KiB/27.59 KiB
# docstring-parser ------------------------------     0 B/36.03 KiB
# pydeck     ------------------------------     0 B/6.58 MiB
# botocore   ------------------------------     0 B/13.40 MiB
# wandb      ------------------------------     0 B/21.79 MiB
# inspect-ai ------------------------------     0 B/32.96 MiB
# ⠙ Preparing packages... (0/55)
# jsonpointer ------------------------------     0 B/7.42 KiB
# jsonlines  ------------------------------     0 B/8.50 KiB
# cachetools ------------------------------     0 B/11.28 KiB
# jsonpatch  ------------------------------     0 B/12.60 KiB
# frozendict ------------------------------     0 B/15.88 KiB
# semver     ------------------------------     0 B/17.49 KiB
# smmap      ------------------------------ 14.88 KiB/23.73 KiB
# tenacity   ------------------------------ 14.88 KiB/27.59 KiB
# docstring-parser ------------------------------     0 B/36.03 KiB
# pydeck     ------------------------------     0 B/6.58 MiB
# streamlit  ------------------------------     0 B/8.69 MiB
# botocore   ------------------------------     0 B/13.40 MiB
# wandb      ------------------------------     0 B/21.79 MiB
# inspect-ai ------------------------------     0 B/32.96 MiB
# ⠙ Preparing packages... (0/55)
# jsonpointer ------------------------------ 7.42 KiB/7.42 KiB
# blinker    ------------------------------ 6.91 KiB/8.26 KiB
# jsonlines  ------------------------------ 8.50 KiB/8.50 KiB
# shortuuid  ------------------------------ 10.28 KiB/10.28 KiB
# cachetools ------------------------------ 11.28 KiB/11.28 KiB
# jsonpatch  ------------------------------ 12.60 KiB/12.60 KiB
# frozendict ------------------------------ 14.91 KiB/15.88 KiB
# semver     ------------------------------ 14.91 KiB/17.49 KiB
# linkify-it-py ------------------------------ 14.92 KiB/19.36 KiB
# smmap      ------------------------------ 14.88 KiB/23.73 KiB
# tenacity   ------------------------------ 14.88 KiB/27.59 KiB
# s3fs       ------------------------------ 14.88 KiB/29.61 KiB
# docstring-parser ------------------------------ 14.87 KiB/36.03 KiB
# mdit-py-plugins ------------------------------ 14.91 KiB/55.86 KiB
# gitdb      ------------------------------ 14.91 KiB/61.32 KiB
# watchdog   ------------------------------ 14.91 KiB/77.22 KiB
# universal-pathlib ------------------------------ 14.90 KiB/80.67 KiB
# mmh3       ------------------------------ 14.91 KiB/100.89 KiB
# dill       ------------------------------ 14.88 KiB/116.86 KiB
# boto3      ------------------------------ 14.91 KiB/136.06 KiB
# multiprocess ------------------------------ 14.90 KiB/146.76 KiB
# transformer-lens ------------------------------ 14.90 KiB/184.83 KiB
# ⠙ Preparing packages... (0/55)
# jsonpointer ------------------------------ 7.42 KiB/7.42 KiB
# blinker    ------------------------------ 6.91 KiB/8.26 KiB
# jsonlines  ------------------------------ 8.50 KiB/8.50 KiB
# jsonref    ------------------------------ 9.20 KiB/9.20 KiB
# shortuuid  ------------------------------ 10.28 KiB/10.28 KiB
# cachetools ------------------------------ 11.28 KiB/11.28 KiB
# jsonpatch  ------------------------------ 12.60 KiB/12.60 KiB
# frozendict ------------------------------ 14.91 KiB/15.88 KiB
# semver     ------------------------------ 14.91 KiB/17.49 KiB
# pathlib-abc ------------------------------ 14.88 KiB/18.62 KiB
# linkify-it-py ------------------------------ 14.92 KiB/19.36 KiB
# wadler-lindig ------------------------------ 14.91 KiB/20.04 KiB
# aioitertools ------------------------------ 14.88 KiB/23.62 KiB
# smmap      ------------------------------ 14.88 KiB/23.73 KiB
# tenacity   ------------------------------ 14.88 KiB/27.59 KiB
# jsonpath-ng ------------------------------ 14.91 KiB/29.40 KiB
# s3fs       ------------------------------ 14.88 KiB/29.61 KiB
# typeguard  ------------------------------ 14.91 KiB/34.96 KiB
# aioboto3   ------------------------------ 14.91 KiB/35.07 KiB
# docstring-parser ------------------------------ 14.87 KiB/36.03 KiB
# ply        ------------------------------ 14.86 KiB/48.41 KiB
# jaxtyping  ------------------------------ 14.91 KiB/54.52 KiB
# ⠙ Preparing packages... (0/55)
# jsonpointer ------------------------------ 7.42 KiB/7.42 KiB
# blinker    ------------------------------ 6.91 KiB/8.26 KiB
# jsonref    ------------------------------ 9.20 KiB/9.20 KiB
# shortuuid  ------------------------------ 10.28 KiB/10.28 KiB
# cachetools ------------------------------ 11.28 KiB/11.28 KiB
# jsonpatch  ------------------------------ 12.60 KiB/12.60 KiB
# frozendict ------------------------------ 14.91 KiB/15.88 KiB
# semver     ------------------------------ 14.91 KiB/17.49 KiB
# pathlib-abc ------------------------------ 18.62 KiB/18.62 KiB
# linkify-it-py ------------------------------ 14.92 KiB/19.36 KiB
# wadler-lindig ------------------------------ 20.04 KiB/20.04 KiB
# aioitertools ------------------------------ 14.88 KiB/23.62 KiB
# smmap      ------------------------------ 23.73 KiB/23.73 KiB
# tenacity   ------------------------------ 17.64 KiB/27.59 KiB
# jsonpath-ng ------------------------------ 14.91 KiB/29.40 KiB
# s3fs       ------------------------------ 29.61 KiB/29.61 KiB
# typeguard  ------------------------------ 14.91 KiB/34.96 KiB
# aioboto3   ------------------------------ 14.91 KiB/35.07 KiB
# docstring-parser ------------------------------ 30.87 KiB/36.03 KiB
# ply        ------------------------------ 46.86 KiB/48.41 KiB
# jaxtyping  ------------------------------ 30.91 KiB/54.52 KiB
# mdit-py-plugins ------------------------------ 14.91 KiB/55.86 KiB
# ⠙ Preparing packages... (0/55)
# jsonpointer ------------------------------ 7.42 KiB/7.42 KiB
# blinker    ------------------------------ 6.91 KiB/8.26 KiB
# jsonref    ------------------------------ 9.20 KiB/9.20 KiB
# shortuuid  ------------------------------ 10.28 KiB/10.28 KiB
# cachetools ------------------------------ 11.28 KiB/11.28 KiB
# jsonpatch  ------------------------------ 12.60 KiB/12.60 KiB
# frozendict ------------------------------ 14.91 KiB/15.88 KiB
# semver     ------------------------------ 14.91 KiB/17.49 KiB
# pathlib-abc ------------------------------ 18.62 KiB/18.62 KiB
# linkify-it-py ------------------------------ 14.92 KiB/19.36 KiB
# wadler-lindig ------------------------------ 20.04 KiB/20.04 KiB
# aioitertools ------------------------------ 14.88 KiB/23.62 KiB
# smmap      ------------------------------ 23.73 KiB/23.73 KiB
# tenacity   ------------------------------ 17.64 KiB/27.59 KiB
# jsonpath-ng ------------------------------ 14.91 KiB/29.40 KiB
# s3fs       ------------------------------ 29.61 KiB/29.61 KiB
# typeguard  ------------------------------ 14.91 KiB/34.96 KiB
# aioboto3   ------------------------------ 14.91 KiB/35.07 KiB
# docstring-parser ------------------------------ 30.87 KiB/36.03 KiB
# ply        ------------------------------ 46.86 KiB/48.41 KiB
# jaxtyping  ------------------------------ 30.91 KiB/54.52 KiB
# mdit-py-plugins ------------------------------ 14.91 KiB/55.86 KiB
# ⠙ Preparing packages... (0/55)
# blinker    ------------------------------ 8.26 KiB/8.26 KiB
# jsonref    ------------------------------ 9.20 KiB/9.20 KiB
# shortuuid  ------------------------------ 10.28 KiB/10.28 KiB
# cachetools ------------------------------ 11.28 KiB/11.28 KiB
# jsonpatch  ------------------------------ 12.60 KiB/12.60 KiB
# frozendict ------------------------------ 14.91 KiB/15.88 KiB
# semver     ------------------------------ 17.49 KiB/17.49 KiB
# pathlib-abc ------------------------------ 18.62 KiB/18.62 KiB
# linkify-it-py ------------------------------ 19.36 KiB/19.36 KiB
# wadler-lindig ------------------------------ 20.04 KiB/20.04 KiB
# aioitertools ------------------------------ 14.88 KiB/23.62 KiB
# smmap      ------------------------------ 23.73 KiB/23.73 KiB
# tenacity   ------------------------------ 27.59 KiB/27.59 KiB
# jsonpath-ng ------------------------------ 14.91 KiB/29.40 KiB
# s3fs       ------------------------------ 29.61 KiB/29.61 KiB
# typeguard  ------------------------------ 30.91 KiB/34.96 KiB
# aioboto3   ------------------------------ 14.91 KiB/35.07 KiB
# docstring-parser ------------------------------ 30.87 KiB/36.03 KiB
# ply        ------------------------------ 46.86 KiB/48.41 KiB
# jaxtyping  ------------------------------ 30.91 KiB/54.52 KiB
# mdit-py-plugins ------------------------------ 14.91 KiB/55.86 KiB
# gitdb      ------------------------------ 30.91 KiB/61.32 KiB
# ⠙ Preparing packages... (0/55)
# blinker    ------------------------------ 8.26 KiB/8.26 KiB
# shortuuid  ------------------------------ 10.28 KiB/10.28 KiB
# cachetools ------------------------------ 11.28 KiB/11.28 KiB
# jsonpatch  ------------------------------ 12.60 KiB/12.60 KiB
# frozendict ------------------------------ 14.91 KiB/15.88 KiB
# semver     ------------------------------ 17.49 KiB/17.49 KiB
# pathlib-abc ------------------------------ 18.62 KiB/18.62 KiB
# linkify-it-py ------------------------------ 19.36 KiB/19.36 KiB
# wadler-lindig ------------------------------ 20.04 KiB/20.04 KiB
# aioitertools ------------------------------ 14.88 KiB/23.62 KiB
# smmap      ------------------------------ 23.73 KiB/23.73 KiB
# tenacity   ------------------------------ 27.59 KiB/27.59 KiB
# jsonpath-ng ------------------------------ 14.91 KiB/29.40 KiB
# s3fs       ------------------------------ 29.61 KiB/29.61 KiB
# typeguard  ------------------------------ 30.91 KiB/34.96 KiB
# aioboto3   ------------------------------ 14.91 KiB/35.07 KiB
# docstring-parser ------------------------------ 30.87 KiB/36.03 KiB
# ply        ------------------------------ 46.86 KiB/48.41 KiB
# jaxtyping  ------------------------------ 30.91 KiB/54.52 KiB
# mdit-py-plugins ------------------------------ 14.91 KiB/55.86 KiB
# gitdb      ------------------------------ 30.91 KiB/61.32 KiB
# einops     ------------------------------ 30.88 KiB/62.85 KiB
# ⠙ Preparing packages... (0/55)
# blinker    ------------------------------ 8.26 KiB/8.26 KiB
# shortuuid  ------------------------------ 10.28 KiB/10.28 KiB
# jsonpatch  ------------------------------ 12.60 KiB/12.60 KiB
# frozendict ------------------------------ 14.91 KiB/15.88 KiB
# semver     ------------------------------ 17.49 KiB/17.49 KiB
# pathlib-abc ------------------------------ 18.62 KiB/18.62 KiB
# linkify-it-py ------------------------------ 19.36 KiB/19.36 KiB
# wadler-lindig ------------------------------ 20.04 KiB/20.04 KiB
# aioitertools ------------------------------ 14.88 KiB/23.62 KiB
# smmap      ------------------------------ 23.73 KiB/23.73 KiB
# tenacity   ------------------------------ 27.59 KiB/27.59 KiB
# jsonpath-ng ------------------------------ 14.91 KiB/29.40 KiB
# s3fs       ------------------------------ 29.61 KiB/29.61 KiB
# typeguard  ------------------------------ 30.91 KiB/34.96 KiB
# aioboto3   ------------------------------ 14.91 KiB/35.07 KiB
# docstring-parser ------------------------------ 30.87 KiB/36.03 KiB
# ply        ------------------------------ 46.86 KiB/48.41 KiB
# jaxtyping  ------------------------------ 30.91 KiB/54.52 KiB
# mdit-py-plugins ------------------------------ 14.91 KiB/55.86 KiB
# gitdb      ------------------------------ 46.91 KiB/61.32 KiB
# einops     ------------------------------ 30.88 KiB/62.85 KiB
# watchdog   ------------------------------ 30.91 KiB/77.22 KiB
# ⠙ Preparing packages... (0/55)
# shortuuid  ------------------------------ 10.28 KiB/10.28 KiB
# jsonpatch  ------------------------------ 12.60 KiB/12.60 KiB
# frozendict ------------------------------ 14.91 KiB/15.88 KiB
# semver     ------------------------------ 17.49 KiB/17.49 KiB
# pathlib-abc ------------------------------ 18.62 KiB/18.62 KiB
# linkify-it-py ------------------------------ 19.36 KiB/19.36 KiB
# wadler-lindig ------------------------------ 20.04 KiB/20.04 KiB
# aioitertools ------------------------------ 14.88 KiB/23.62 KiB
# smmap      ------------------------------ 23.73 KiB/23.73 KiB
# tenacity   ------------------------------ 27.59 KiB/27.59 KiB
# jsonpath-ng ------------------------------ 14.91 KiB/29.40 KiB
# s3fs       ------------------------------ 29.61 KiB/29.61 KiB
# typeguard  ------------------------------ 30.91 KiB/34.96 KiB
# aioboto3   ------------------------------ 14.91 KiB/35.07 KiB
# docstring-parser ------------------------------ 30.87 KiB/36.03 KiB
# ply        ------------------------------ 46.86 KiB/48.41 KiB
# jaxtyping  ------------------------------ 30.91 KiB/54.52 KiB
# mdit-py-plugins ------------------------------ 14.91 KiB/55.86 KiB
# gitdb      ------------------------------ 46.91 KiB/61.32 KiB
# einops     ------------------------------ 30.88 KiB/62.85 KiB
# watchdog   ------------------------------ 30.91 KiB/77.22 KiB
# universal-pathlib ------------------------------ 21.82 KiB/80.67 KiB
# ⠙ Preparing packages... (0/55)
# shortuuid  ------------------------------ 10.28 KiB/10.28 KiB
# frozendict ------------------------------ 14.91 KiB/15.88 KiB
# semver     ------------------------------ 17.49 KiB/17.49 KiB
# pathlib-abc ------------------------------ 18.62 KiB/18.62 KiB
# linkify-it-py ------------------------------ 19.36 KiB/19.36 KiB
# wadler-lindig ------------------------------ 20.04 KiB/20.04 KiB
# aioitertools ------------------------------ 14.88 KiB/23.62 KiB
# smmap      ------------------------------ 23.73 KiB/23.73 KiB
# tenacity   ------------------------------ 27.59 KiB/27.59 KiB
# jsonpath-ng ------------------------------ 14.91 KiB/29.40 KiB
# s3fs       ------------------------------ 29.61 KiB/29.61 KiB
# typeguard  ------------------------------ 30.91 KiB/34.96 KiB
# aioboto3   ------------------------------ 14.91 KiB/35.07 KiB
# docstring-parser ------------------------------ 30.87 KiB/36.03 KiB
# ply        ------------------------------ 46.86 KiB/48.41 KiB
# jaxtyping  ------------------------------ 30.91 KiB/54.52 KiB
# mdit-py-plugins ------------------------------ 14.91 KiB/55.86 KiB
# gitdb      ------------------------------ 46.91 KiB/61.32 KiB
# einops     ------------------------------ 30.88 KiB/62.85 KiB
# watchdog   ------------------------------ 30.91 KiB/77.22 KiB
# universal-pathlib ------------------------------ 21.82 KiB/80.67 KiB
# s3transfer ------------------------------ 46.88 KiB/83.70 KiB
# ⠙ Preparing packages... (0/55)
# shortuuid  ------------------------------ 10.28 KiB/10.28 KiB
# frozendict ------------------------------ 14.91 KiB/15.88 KiB
# semver     ------------------------------ 17.49 KiB/17.49 KiB
# linkify-it-py ------------------------------ 19.36 KiB/19.36 KiB
# wadler-lindig ------------------------------ 20.04 KiB/20.04 KiB
# aioitertools ------------------------------ 14.88 KiB/23.62 KiB
# smmap      ------------------------------ 23.73 KiB/23.73 KiB
# tenacity   ------------------------------ 27.59 KiB/27.59 KiB
# jsonpath-ng ------------------------------ 14.91 KiB/29.40 KiB
# s3fs       ------------------------------ 29.61 KiB/29.61 KiB
# typeguard  ------------------------------ 30.91 KiB/34.96 KiB
# aioboto3   ------------------------------ 14.91 KiB/35.07 KiB
# docstring-parser ------------------------------ 30.87 KiB/36.03 KiB
# ply        ------------------------------ 46.86 KiB/48.41 KiB
# jaxtyping  ------------------------------ 30.91 KiB/54.52 KiB
# mdit-py-plugins ------------------------------ 14.91 KiB/55.86 KiB
# gitdb      ------------------------------ 46.91 KiB/61.32 KiB
# einops     ------------------------------ 30.88 KiB/62.85 KiB
# watchdog   ------------------------------ 30.91 KiB/77.22 KiB
# universal-pathlib ------------------------------ 21.82 KiB/80.67 KiB
# s3transfer ------------------------------ 46.88 KiB/83.70 KiB
# aiobotocore ------------------------------ 14.88 KiB/84.02 KiB
# ⠙ Preparing packages... (0/55)
# shortuuid  ------------------------------ 10.28 KiB/10.28 KiB
# frozendict ------------------------------ 14.91 KiB/15.88 KiB
# semver     ------------------------------ 17.49 KiB/17.49 KiB
# linkify-it-py ------------------------------ 19.36 KiB/19.36 KiB
# aioitertools ------------------------------ 14.88 KiB/23.62 KiB
# smmap      ------------------------------ 23.73 KiB/23.73 KiB
# tenacity   ------------------------------ 27.59 KiB/27.59 KiB
# jsonpath-ng ------------------------------ 14.91 KiB/29.40 KiB
# s3fs       ------------------------------ 29.61 KiB/29.61 KiB
# typeguard  ------------------------------ 30.91 KiB/34.96 KiB
# aioboto3   ------------------------------ 14.91 KiB/35.07 KiB
# docstring-parser ------------------------------ 30.87 KiB/36.03 KiB
# ply        ------------------------------ 46.86 KiB/48.41 KiB
# jaxtyping  ------------------------------ 30.91 KiB/54.52 KiB
# mdit-py-plugins ------------------------------ 14.91 KiB/55.86 KiB
# gitdb      ------------------------------ 46.91 KiB/61.32 KiB
# einops     ------------------------------ 30.88 KiB/62.85 KiB
# watchdog   ------------------------------ 30.91 KiB/77.22 KiB
# universal-pathlib ------------------------------ 21.82 KiB/80.67 KiB
# s3transfer ------------------------------ 46.88 KiB/83.70 KiB
# aiobotocore ------------------------------ 14.88 KiB/84.02 KiB
# mmh3       ------------------------------ 98.72 KiB/100.89 KiB
# ⠙ Preparing packages... (0/55)
# nest-asyncio2 ------------------------------     0 B/7.33 KiB
# shortuuid  ------------------------------ 10.28 KiB/10.28 KiB
# frozendict ------------------------------ 15.88 KiB/15.88 KiB
# semver     ------------------------------ 17.49 KiB/17.49 KiB
# aioitertools ------------------------------ 14.88 KiB/23.62 KiB
# smmap      ------------------------------ 23.73 KiB/23.73 KiB
# tenacity   ------------------------------ 27.59 KiB/27.59 KiB
# jsonpath-ng ------------------------------ 14.91 KiB/29.40 KiB
# s3fs       ------------------------------ 29.61 KiB/29.61 KiB
# typeguard  ------------------------------ 30.91 KiB/34.96 KiB
# aioboto3   ------------------------------ 14.91 KiB/35.07 KiB
# docstring-parser ------------------------------ 30.87 KiB/36.03 KiB
# ply        ------------------------------ 46.86 KiB/48.41 KiB
# jaxtyping  ------------------------------ 46.91 KiB/54.52 KiB
# mdit-py-plugins ------------------------------ 14.91 KiB/55.86 KiB
# gitdb      ------------------------------ 46.91 KiB/61.32 KiB
# einops     ------------------------------ 30.88 KiB/62.85 KiB
# watchdog   ------------------------------ 30.91 KiB/77.22 KiB
# universal-pathlib ------------------------------ 39.69 KiB/80.67 KiB
# s3transfer ------------------------------ 46.88 KiB/83.70 KiB
# aiobotocore ------------------------------ 14.88 KiB/84.02 KiB
# mmh3       ------------------------------ 98.72 KiB/100.89 KiB
# ⠹ Preparing packages... (6/55)
# nest-asyncio2 ------------------------------     0 B/7.33 KiB
# shortuuid  ------------------------------ 10.28 KiB/10.28 KiB
# frozendict ------------------------------ 15.88 KiB/15.88 KiB
# semver     ------------------------------ 17.49 KiB/17.49 KiB
# aioitertools ------------------------------ 14.88 KiB/23.62 KiB
# smmap      ------------------------------ 23.73 KiB/23.73 KiB
# tenacity   ------------------------------ 27.59 KiB/27.59 KiB
# jsonpath-ng ------------------------------ 14.91 KiB/29.40 KiB
# s3fs       ------------------------------ 29.61 KiB/29.61 KiB
# typeguard  ------------------------------ 30.91 KiB/34.96 KiB
# aioboto3   ------------------------------ 14.91 KiB/35.07 KiB
# docstring-parser ------------------------------ 30.87 KiB/36.03 KiB
# ply        ------------------------------ 46.86 KiB/48.41 KiB
# jaxtyping  ------------------------------ 46.91 KiB/54.52 KiB
# mdit-py-plugins ------------------------------ 14.91 KiB/55.86 KiB
# gitdb      ------------------------------ 46.91 KiB/61.32 KiB
# einops     ------------------------------ 30.88 KiB/62.85 KiB
# watchdog   ------------------------------ 30.91 KiB/77.22 KiB
# universal-pathlib ------------------------------ 39.69 KiB/80.67 KiB
# s3transfer ------------------------------ 46.88 KiB/83.70 KiB
# aiobotocore ------------------------------ 14.88 KiB/84.02 KiB
# mmh3       ------------------------------ 98.72 KiB/100.89 KiB
# Building transformers-stream-generator==0.0.5
# ⠹ Preparing packages... (6/55)
# nest-asyncio2 ------------------------------     0 B/7.33 KiB
# shortuuid  ------------------------------ 10.28 KiB/10.28 KiB
# frozendict ------------------------------ 15.88 KiB/15.88 KiB
# aioitertools ------------------------------ 14.88 KiB/23.62 KiB
# smmap      ------------------------------ 23.73 KiB/23.73 KiB
# tenacity   ------------------------------ 27.59 KiB/27.59 KiB
# jsonpath-ng ------------------------------ 14.91 KiB/29.40 KiB
# s3fs       ------------------------------ 29.61 KiB/29.61 KiB
# typeguard  ------------------------------ 30.91 KiB/34.96 KiB
# aioboto3   ------------------------------ 14.91 KiB/35.07 KiB
# docstring-parser ------------------------------ 30.87 KiB/36.03 KiB
# ply        ------------------------------ 46.86 KiB/48.41 KiB
# jaxtyping  ------------------------------ 46.91 KiB/54.52 KiB
# mdit-py-plugins ------------------------------ 14.91 KiB/55.86 KiB
# gitdb      ------------------------------ 46.91 KiB/61.32 KiB
# einops     ------------------------------ 30.88 KiB/62.85 KiB
# watchdog   ------------------------------ 30.91 KiB/77.22 KiB
# universal-pathlib ------------------------------ 39.69 KiB/80.67 KiB
# s3transfer ------------------------------ 46.88 KiB/83.70 KiB
# aiobotocore ------------------------------ 14.88 KiB/84.02 KiB
# mmh3       ------------------------------ 98.72 KiB/100.89 KiB
# Building transformers-stream-generator==0.0.5
# ⠹ Preparing packages... (6/55)
# nest-asyncio2 ------------------------------     0 B/7.33 KiB
# shortuuid  ------------------------------ 10.28 KiB/10.28 KiB
# aioitertools ------------------------------ 14.88 KiB/23.62 KiB
# smmap      ------------------------------ 23.73 KiB/23.73 KiB
# tenacity   ------------------------------ 27.59 KiB/27.59 KiB
# jsonpath-ng ------------------------------ 14.91 KiB/29.40 KiB
# s3fs       ------------------------------ 29.61 KiB/29.61 KiB
# typeguard  ------------------------------ 30.91 KiB/34.96 KiB
# aioboto3   ------------------------------ 14.91 KiB/35.07 KiB
# docstring-parser ------------------------------ 30.87 KiB/36.03 KiB
# ply        ------------------------------ 46.86 KiB/48.41 KiB
# jaxtyping  ------------------------------ 46.91 KiB/54.52 KiB
# mdit-py-plugins ------------------------------ 14.91 KiB/55.86 KiB
# gitdb      ------------------------------ 46.91 KiB/61.32 KiB
# einops     ------------------------------ 30.88 KiB/62.85 KiB
# watchdog   ------------------------------ 30.91 KiB/77.22 KiB
# universal-pathlib ------------------------------ 39.69 KiB/80.67 KiB
# s3transfer ------------------------------ 46.88 KiB/83.70 KiB
# aiobotocore ------------------------------ 14.88 KiB/84.02 KiB
# mmh3       ------------------------------ 98.72 KiB/100.89 KiB
# dill       ------------------------------ 62.88 KiB/116.86 KiB
# Building transformers-stream-generator==0.0.5
# ⠹ Preparing packages... (6/55)
# nest-asyncio2 ------------------------------     0 B/7.33 KiB
# shortuuid  ------------------------------ 10.28 KiB/10.28 KiB
# aioitertools ------------------------------ 14.88 KiB/23.62 KiB
# tenacity   ------------------------------ 27.59 KiB/27.59 KiB
# jsonpath-ng ------------------------------ 14.91 KiB/29.40 KiB
# s3fs       ------------------------------ 29.61 KiB/29.61 KiB
# typeguard  ------------------------------ 30.91 KiB/34.96 KiB
# aioboto3   ------------------------------ 14.91 KiB/35.07 KiB
# docstring-parser ------------------------------ 30.87 KiB/36.03 KiB
# ply        ------------------------------ 48.41 KiB/48.41 KiB
# jaxtyping  ------------------------------ 46.91 KiB/54.52 KiB
# mdit-py-plugins ------------------------------ 14.91 KiB/55.86 KiB
# gitdb      ------------------------------ 46.91 KiB/61.32 KiB
# einops     ------------------------------ 30.88 KiB/62.85 KiB
# watchdog   ------------------------------ 30.91 KiB/77.22 KiB
# universal-pathlib ------------------------------ 39.69 KiB/80.67 KiB
# s3transfer ------------------------------ 62.88 KiB/83.70 KiB
# aiobotocore ------------------------------ 30.88 KiB/84.02 KiB
# mmh3       ------------------------------ 100.89 KiB/100.89 KiB
# dill       ------------------------------ 62.88 KiB/116.86 KiB
# boto3      ------------------------------ 30.91 KiB/136.06 KiB
# Building transformers-stream-generator==0.0.5
# ⠹ Preparing packages... (6/55)
# better-abc ------------------------------     0 B/3.39 KiB
# uc-micro-py ------------------------------     0 B/6.08 KiB
# fancy-einsum ------------------------------ 6.09 KiB/6.09 KiB
# nest-asyncio2 ------------------------------ 7.33 KiB/7.33 KiB
# shortuuid  ------------------------------ 10.28 KiB/10.28 KiB
# aioitertools ------------------------------ 14.88 KiB/23.62 KiB
# tenacity   ------------------------------ 27.59 KiB/27.59 KiB
# jsonpath-ng ------------------------------ 14.91 KiB/29.40 KiB
# s3fs       ------------------------------ 29.61 KiB/29.61 KiB
# typeguard  ------------------------------ 30.91 KiB/34.96 KiB
# aioboto3   ------------------------------ 14.91 KiB/35.07 KiB
# docstring-parser ------------------------------ 30.87 KiB/36.03 KiB
# ply        ------------------------------ 48.41 KiB/48.41 KiB
# jaxtyping  ------------------------------ 46.91 KiB/54.52 KiB
# mdit-py-plugins ------------------------------ 14.91 KiB/55.86 KiB
# gitdb      ------------------------------ 46.91 KiB/61.32 KiB
# einops     ------------------------------ 30.88 KiB/62.85 KiB
# watchdog   ------------------------------ 30.91 KiB/77.22 KiB
# universal-pathlib ------------------------------ 39.69 KiB/80.67 KiB
# s3transfer ------------------------------ 62.88 KiB/83.70 KiB
# aiobotocore ------------------------------ 30.88 KiB/84.02 KiB
# Building transformers-stream-generator==0.0.5
# ⠹ Preparing packages... (6/55)
# better-abc ------------------------------     0 B/3.39 KiB
# uc-micro-py ------------------------------     0 B/6.08 KiB
# fancy-einsum ------------------------------ 6.09 KiB/6.09 KiB
# nest-asyncio2 ------------------------------ 7.33 KiB/7.33 KiB
# shortuuid  ------------------------------ 10.28 KiB/10.28 KiB
# aioitertools ------------------------------ 14.88 KiB/23.62 KiB
# tenacity   ------------------------------ 27.59 KiB/27.59 KiB
# jsonpath-ng ------------------------------ 22.52 KiB/29.40 KiB
# typeguard  ------------------------------ 30.91 KiB/34.96 KiB
# aioboto3   ------------------------------ 14.91 KiB/35.07 KiB
# docstring-parser ------------------------------ 30.87 KiB/36.03 KiB
# ply        ------------------------------ 48.41 KiB/48.41 KiB
# jaxtyping  ------------------------------ 46.91 KiB/54.52 KiB
# mdit-py-plugins ------------------------------ 14.91 KiB/55.86 KiB
# gitdb      ------------------------------ 46.91 KiB/61.32 KiB
# einops     ------------------------------ 30.88 KiB/62.85 KiB
# watchdog   ------------------------------ 30.91 KiB/77.22 KiB
# universal-pathlib ------------------------------ 55.69 KiB/80.67 KiB
# s3transfer ------------------------------ 62.88 KiB/83.70 KiB
# aiobotocore ------------------------------ 30.88 KiB/84.02 KiB
# mmh3       ------------------------------ 100.89 KiB/100.89 KiB
# Building transformers-stream-generator==0.0.5
# ⠹ Preparing packages... (6/55)
# better-abc ------------------------------     0 B/3.39 KiB
# uc-micro-py ------------------------------     0 B/6.08 KiB
# fancy-einsum ------------------------------ 6.09 KiB/6.09 KiB
# nest-asyncio2 ------------------------------ 7.33 KiB/7.33 KiB
# aioitertools ------------------------------ 23.62 KiB/23.62 KiB
# tenacity   ------------------------------ 27.59 KiB/27.59 KiB
# jsonpath-ng ------------------------------ 22.52 KiB/29.40 KiB
# typeguard  ------------------------------ 30.91 KiB/34.96 KiB
# aioboto3   ------------------------------ 14.91 KiB/35.07 KiB
# docstring-parser ------------------------------ 30.87 KiB/36.03 KiB
# ply        ------------------------------ 48.41 KiB/48.41 KiB
# jaxtyping  ------------------------------ 46.91 KiB/54.52 KiB
# mdit-py-plugins ------------------------------ 14.91 KiB/55.86 KiB
# gitdb      ------------------------------ 46.91 KiB/61.32 KiB
# einops     ------------------------------ 30.88 KiB/62.85 KiB
# watchdog   ------------------------------ 46.81 KiB/77.22 KiB
# universal-pathlib ------------------------------ 55.69 KiB/80.67 KiB
# s3transfer ------------------------------ 62.88 KiB/83.70 KiB
# aiobotocore ------------------------------ 30.88 KiB/84.02 KiB
# mmh3       ------------------------------ 100.89 KiB/100.89 KiB
# dill       ------------------------------ 78.88 KiB/116.86 KiB
# Building transformers-stream-generator==0.0.5
# ⠹ Preparing packages... (6/55)
# better-abc ------------------------------     0 B/3.39 KiB
# uc-micro-py ------------------------------     0 B/6.08 KiB
# fancy-einsum ------------------------------ 6.09 KiB/6.09 KiB
# nest-asyncio2 ------------------------------ 7.33 KiB/7.33 KiB
# aioitertools ------------------------------ 23.62 KiB/23.62 KiB
# tenacity   ------------------------------ 27.59 KiB/27.59 KiB
# jsonpath-ng ------------------------------ 22.52 KiB/29.40 KiB
# typeguard  ------------------------------ 30.91 KiB/34.96 KiB
# aioboto3   ------------------------------ 14.91 KiB/35.07 KiB
# docstring-parser ------------------------------ 30.87 KiB/36.03 KiB
# jaxtyping  ------------------------------ 46.91 KiB/54.52 KiB
# mdit-py-plugins ------------------------------ 14.91 KiB/55.86 KiB
# gitdb      ------------------------------ 46.91 KiB/61.32 KiB
# einops     ------------------------------ 30.88 KiB/62.85 KiB
# watchdog   ------------------------------ 46.81 KiB/77.22 KiB
# universal-pathlib ------------------------------ 55.69 KiB/80.67 KiB
# s3transfer ------------------------------ 62.88 KiB/83.70 KiB
# aiobotocore ------------------------------ 30.88 KiB/84.02 KiB
# mmh3       ------------------------------ 100.89 KiB/100.89 KiB
# dill       ------------------------------ 78.88 KiB/116.86 KiB
# boto3      ------------------------------ 30.91 KiB/136.06 KiB
# Building transformers-stream-generator==0.0.5
# ⠹ Preparing packages... (6/55)
# better-abc ------------------------------ 3.39 KiB/3.39 KiB
# uc-micro-py ------------------------------ 3.87 KiB/6.08 KiB
# fancy-einsum ------------------------------ 6.09 KiB/6.09 KiB
# nest-asyncio2 ------------------------------ 7.33 KiB/7.33 KiB
# aioitertools ------------------------------ 23.62 KiB/23.62 KiB
# jsonpath-ng ------------------------------ 22.52 KiB/29.40 KiB
# typeguard  ------------------------------ 30.91 KiB/34.96 KiB
# aioboto3   ------------------------------ 14.91 KiB/35.07 KiB
# docstring-parser ------------------------------ 30.87 KiB/36.03 KiB
# jaxtyping  ------------------------------ 46.91 KiB/54.52 KiB
# mdit-py-plugins ------------------------------ 14.91 KiB/55.86 KiB
# gitdb      ------------------------------ 46.91 KiB/61.32 KiB
# einops     ------------------------------ 30.88 KiB/62.85 KiB
# watchdog   ------------------------------ 46.81 KiB/77.22 KiB
# universal-pathlib ------------------------------ 55.69 KiB/80.67 KiB
# s3transfer ------------------------------ 62.88 KiB/83.70 KiB
# aiobotocore ------------------------------ 30.88 KiB/84.02 KiB
# mmh3       ------------------------------ 100.89 KiB/100.89 KiB
# dill       ------------------------------ 78.88 KiB/116.86 KiB
# boto3      ------------------------------ 30.91 KiB/136.06 KiB
# ijson      ------------------------------ 126.89 KiB/145.53 KiB
# Building transformers-stream-generator==0.0.5
# ⠹ Preparing packages... (6/55)
# better-abc ------------------------------ 3.39 KiB/3.39 KiB
# uc-micro-py ------------------------------ 3.87 KiB/6.08 KiB
# fancy-einsum ------------------------------ 6.09 KiB/6.09 KiB
# nest-asyncio2 ------------------------------ 7.33 KiB/7.33 KiB
# aioitertools ------------------------------ 23.62 KiB/23.62 KiB
# jsonpath-ng ------------------------------ 22.52 KiB/29.40 KiB
# typeguard  ------------------------------ 30.91 KiB/34.96 KiB
# aioboto3   ------------------------------ 14.91 KiB/35.07 KiB
# docstring-parser ------------------------------ 30.87 KiB/36.03 KiB
# jaxtyping  ------------------------------ 46.91 KiB/54.52 KiB
# mdit-py-plugins ------------------------------ 14.91 KiB/55.86 KiB
# gitdb      ------------------------------ 46.91 KiB/61.32 KiB
# einops     ------------------------------ 30.88 KiB/62.85 KiB
# watchdog   ------------------------------ 46.81 KiB/77.22 KiB
# universal-pathlib ------------------------------ 55.69 KiB/80.67 KiB
# s3transfer ------------------------------ 62.88 KiB/83.70 KiB
# aiobotocore ------------------------------ 30.88 KiB/84.02 KiB
# dill       ------------------------------ 78.88 KiB/116.86 KiB
# boto3      ------------------------------ 30.91 KiB/136.06 KiB
# ijson      ------------------------------ 126.89 KiB/145.53 KiB
# multiprocess ------------------------------ 62.90 KiB/146.76 KiB
# Building transformers-stream-generator==0.0.5
# ⠹ Preparing packages... (6/55)
# better-abc ------------------------------ 3.39 KiB/3.39 KiB
# uc-micro-py ------------------------------ 3.87 KiB/6.08 KiB
# fancy-einsum ------------------------------ 6.09 KiB/6.09 KiB
# nest-asyncio2 ------------------------------ 7.33 KiB/7.33 KiB
# aioitertools ------------------------------ 23.62 KiB/23.62 KiB
# jsonpath-ng ------------------------------ 22.52 KiB/29.40 KiB
# typeguard  ------------------------------ 30.91 KiB/34.96 KiB
# aioboto3   ------------------------------ 30.91 KiB/35.07 KiB
# docstring-parser ------------------------------ 30.87 KiB/36.03 KiB
# jaxtyping  ------------------------------ 46.91 KiB/54.52 KiB
# mdit-py-plugins ------------------------------ 14.91 KiB/55.86 KiB
# gitdb      ------------------------------ 46.91 KiB/61.32 KiB
# einops     ------------------------------ 30.88 KiB/62.85 KiB
# watchdog   ------------------------------ 46.81 KiB/77.22 KiB
# universal-pathlib ------------------------------ 55.69 KiB/80.67 KiB
# s3transfer ------------------------------ 78.88 KiB/83.70 KiB
# aiobotocore ------------------------------ 30.88 KiB/84.02 KiB
# dill       ------------------------------ 78.88 KiB/116.86 KiB
# boto3      ------------------------------ 30.91 KiB/136.06 KiB
# ijson      ------------------------------ 126.89 KiB/145.53 KiB
# multiprocess ------------------------------ 62.90 KiB/146.76 KiB
# Building transformers-stream-generator==0.0.5
# ⠹ Preparing packages... (6/55)
# better-abc ------------------------------ 3.39 KiB/3.39 KiB
# uc-micro-py ------------------------------ 3.87 KiB/6.08 KiB
# fancy-einsum ------------------------------ 6.09 KiB/6.09 KiB
# aioitertools ------------------------------ 23.62 KiB/23.62 KiB
# jsonpath-ng ------------------------------ 29.40 KiB/29.40 KiB
# typeguard  ------------------------------ 34.96 KiB/34.96 KiB
# aioboto3   ------------------------------ 35.07 KiB/35.07 KiB
# docstring-parser ------------------------------ 36.03 KiB/36.03 KiB
# jaxtyping  ------------------------------ 54.52 KiB/54.52 KiB
# mdit-py-plugins ------------------------------ 30.91 KiB/55.86 KiB
# gitdb      ------------------------------ 61.32 KiB/61.32 KiB
# einops     ------------------------------ 30.88 KiB/62.85 KiB
# watchdog   ------------------------------ 46.81 KiB/77.22 KiB
# universal-pathlib ------------------------------ 55.69 KiB/80.67 KiB
# s3transfer ------------------------------ 83.70 KiB/83.70 KiB
# aiobotocore ------------------------------ 46.88 KiB/84.02 KiB
# dill       ------------------------------ 78.88 KiB/116.86 KiB
# boto3      ------------------------------ 46.91 KiB/136.06 KiB
# ijson      ------------------------------ 142.89 KiB/145.53 KiB
# multiprocess ------------------------------ 77.51 KiB/146.76 KiB
# transformer-lens ------------------------------ 94.90 KiB/184.83 KiB
# Building transformers-stream-generator==0.0.5
# ⠹ Preparing packages... (6/55)
# better-abc ------------------------------ 3.39 KiB/3.39 KiB
# uc-micro-py ------------------------------ 3.87 KiB/6.08 KiB
# fancy-einsum ------------------------------ 6.09 KiB/6.09 KiB
# aioitertools ------------------------------ 23.62 KiB/23.62 KiB
# typeguard  ------------------------------ 34.96 KiB/34.96 KiB
# aioboto3   ------------------------------ 35.07 KiB/35.07 KiB
# docstring-parser ------------------------------ 36.03 KiB/36.03 KiB
# jaxtyping  ------------------------------ 54.52 KiB/54.52 KiB
# mdit-py-plugins ------------------------------ 30.91 KiB/55.86 KiB
# gitdb      ------------------------------ 61.32 KiB/61.32 KiB
# einops     ------------------------------ 46.88 KiB/62.85 KiB
# watchdog   ------------------------------ 62.70 KiB/77.22 KiB
# universal-pathlib ------------------------------ 55.69 KiB/80.67 KiB
# s3transfer ------------------------------ 83.70 KiB/83.70 KiB
# aiobotocore ------------------------------ 46.88 KiB/84.02 KiB
# dill       ------------------------------ 78.88 KiB/116.86 KiB
# boto3      ------------------------------ 46.91 KiB/136.06 KiB
# ijson      ------------------------------ 142.89 KiB/145.53 KiB
# multiprocess ------------------------------ 77.51 KiB/146.76 KiB
# transformer-lens ------------------------------ 94.90 KiB/184.83 KiB
# fsspec     ------------------------------ 77.30 KiB/194.62 KiB
# Building transformers-stream-generator==0.0.5
# ⠹ Preparing packages... (6/55)
# better-abc ------------------------------ 3.39 KiB/3.39 KiB
# uc-micro-py ------------------------------ 3.87 KiB/6.08 KiB
# fancy-einsum ------------------------------ 6.09 KiB/6.09 KiB
# aioitertools ------------------------------ 23.62 KiB/23.62 KiB
# aioboto3   ------------------------------ 35.07 KiB/35.07 KiB
# docstring-parser ------------------------------ 36.03 KiB/36.03 KiB
# jaxtyping  ------------------------------ 54.52 KiB/54.52 KiB
# mdit-py-plugins ------------------------------ 30.91 KiB/55.86 KiB
# gitdb      ------------------------------ 61.32 KiB/61.32 KiB
# einops     ------------------------------ 46.88 KiB/62.85 KiB
# watchdog   ------------------------------ 62.70 KiB/77.22 KiB
# universal-pathlib ------------------------------ 55.69 KiB/80.67 KiB
# s3transfer ------------------------------ 83.70 KiB/83.70 KiB
# aiobotocore ------------------------------ 46.88 KiB/84.02 KiB
# dill       ------------------------------ 78.88 KiB/116.86 KiB
# boto3      ------------------------------ 46.91 KiB/136.06 KiB
# ijson      ------------------------------ 142.89 KiB/145.53 KiB
# multiprocess ------------------------------ 77.51 KiB/146.76 KiB
# transformer-lens ------------------------------ 94.90 KiB/184.83 KiB
# fsspec     ------------------------------ 77.30 KiB/194.62 KiB
# gitpython  ------------------------------ 117.61 KiB/203.73 KiB
# Building transformers-stream-generator==0.0.5
# ⠹ Preparing packages... (6/55)
# better-abc ------------------------------ 3.39 KiB/3.39 KiB
# uc-micro-py ------------------------------ 3.87 KiB/6.08 KiB
# fancy-einsum ------------------------------ 6.09 KiB/6.09 KiB
# aioboto3   ------------------------------ 35.07 KiB/35.07 KiB
# docstring-parser ------------------------------ 36.03 KiB/36.03 KiB
# jaxtyping  ------------------------------ 54.52 KiB/54.52 KiB
# mdit-py-plugins ------------------------------ 30.91 KiB/55.86 KiB
# gitdb      ------------------------------ 61.32 KiB/61.32 KiB
# einops     ------------------------------ 46.88 KiB/62.85 KiB
# watchdog   ------------------------------ 62.70 KiB/77.22 KiB
# universal-pathlib ------------------------------ 55.69 KiB/80.67 KiB
# s3transfer ------------------------------ 83.70 KiB/83.70 KiB
# aiobotocore ------------------------------ 46.88 KiB/84.02 KiB
# dill       ------------------------------ 78.88 KiB/116.86 KiB
# boto3      ------------------------------ 46.91 KiB/136.06 KiB
# ijson      ------------------------------ 142.89 KiB/145.53 KiB
# multiprocess ------------------------------ 77.51 KiB/146.76 KiB
# transformer-lens ------------------------------ 94.90 KiB/184.83 KiB
# fsspec     ------------------------------ 94.88 KiB/194.62 KiB
# gitpython  ------------------------------ 117.61 KiB/203.73 KiB
# rich       ------------------------------ 62.88 KiB/237.69 KiB
# Building transformers-stream-generator==0.0.5
# ⠹ Preparing packages... (6/55)
# better-abc ------------------------------ 3.39 KiB/3.39 KiB
# uc-micro-py ------------------------------ 3.87 KiB/6.08 KiB
# fancy-einsum ------------------------------ 6.09 KiB/6.09 KiB
# aioboto3   ------------------------------ 35.07 KiB/35.07 KiB
# jaxtyping  ------------------------------ 54.52 KiB/54.52 KiB
# mdit-py-plugins ------------------------------ 30.91 KiB/55.86 KiB
# gitdb      ------------------------------ 61.32 KiB/61.32 KiB
# einops     ------------------------------ 46.88 KiB/62.85 KiB
# watchdog   ------------------------------ 62.70 KiB/77.22 KiB
# universal-pathlib ------------------------------ 55.69 KiB/80.67 KiB
# s3transfer ------------------------------ 83.70 KiB/83.70 KiB
# aiobotocore ------------------------------ 46.88 KiB/84.02 KiB
# dill       ------------------------------ 78.88 KiB/116.86 KiB
# boto3      ------------------------------ 46.91 KiB/136.06 KiB
# ijson      ------------------------------ 142.89 KiB/145.53 KiB
# multiprocess ------------------------------ 77.51 KiB/146.76 KiB
# transformer-lens ------------------------------ 94.90 KiB/184.83 KiB
# fsspec     ------------------------------ 94.88 KiB/194.62 KiB
# gitpython  ------------------------------ 117.61 KiB/203.73 KiB
# rich       ------------------------------ 62.88 KiB/237.69 KiB
# sentry-sdk ------------------------------ 62.84 KiB/415.00 KiB
# Building transformers-stream-generator==0.0.5
# ⠹ Preparing packages... (6/55)
# better-abc ------------------------------ 3.39 KiB/3.39 KiB
# uc-micro-py ------------------------------ 3.87 KiB/6.08 KiB
# fancy-einsum ------------------------------ 6.09 KiB/6.09 KiB
# aioboto3   ------------------------------ 35.07 KiB/35.07 KiB
# jaxtyping  ------------------------------ 54.52 KiB/54.52 KiB
# mdit-py-plugins ------------------------------ 30.91 KiB/55.86 KiB
# gitdb      ------------------------------ 61.32 KiB/61.32 KiB
# einops     ------------------------------ 46.88 KiB/62.85 KiB
# watchdog   ------------------------------ 62.70 KiB/77.22 KiB
# universal-pathlib ------------------------------ 55.69 KiB/80.67 KiB
# s3transfer ------------------------------ 83.70 KiB/83.70 KiB
# aiobotocore ------------------------------ 46.88 KiB/84.02 KiB
# dill       ------------------------------ 78.88 KiB/116.86 KiB
# boto3      ------------------------------ 46.91 KiB/136.06 KiB
# ijson      ------------------------------ 142.89 KiB/145.53 KiB
# multiprocess ------------------------------ 77.51 KiB/146.76 KiB
# transformer-lens ------------------------------ 94.90 KiB/184.83 KiB
# fsspec     ------------------------------ 94.88 KiB/194.62 KiB
# gitpython  ------------------------------ 117.61 KiB/203.73 KiB
# rich       ------------------------------ 62.88 KiB/237.69 KiB
# sentry-sdk ------------------------------ 62.84 KiB/415.00 KiB
# Building transformers-stream-generator==0.0.5
# ⠹ Preparing packages... (6/55)
# ...
# inspect-ai ------------------------------ 2.84 MiB/32.96 MiB
# Building transformers-stream-generator==0.0.5
# ⠦ Preparing packages... (47/55)
# pydeck     ------------------------------ 3.58 MiB/6.58 MiB
# streamlit  ------------------------------ 847.65 KiB/8.69 MiB
# botocore   ------------------------------ 1.89 MiB/13.40 MiB
# wandb      ------------------------------ 3.68 MiB/21.79 MiB
# inspect-ai ------------------------------ 2.89 MiB/32.96 MiB
# Building transformers-stream-generator==0.0.5
# ⠦ Preparing packages... (47/55)
# pydeck     ------------------------------ 3.80 MiB/6.58 MiB
# streamlit  ------------------------------ 975.65 KiB/8.69 MiB
# botocore   ------------------------------ 2.13 MiB/13.40 MiB
# wandb      ------------------------------ 3.89 MiB/21.79 MiB
# inspect-ai ------------------------------ 2.91 MiB/32.96 MiB
# Building transformers-stream-generator==0.0.5
# ⠧ Preparing packages... (48/55)
# pydeck     ------------------------------ 4.00 MiB/6.58 MiB
# streamlit  ------------------------------ 1.73 MiB/8.69 MiB
# botocore   ------------------------------ 2.28 MiB/13.40 MiB
# wandb      ------------------------------ 4.09 MiB/21.79 MiB
# inspect-ai ------------------------------ 2.95 MiB/32.96 MiB
# Building transformers-stream-generator==0.0.5
# ⠧ Preparing packages... (48/55)
# pydeck     ------------------------------ 4.26 MiB/6.58 MiB
# streamlit  ------------------------------ 2.59 MiB/8.69 MiB
# botocore   ------------------------------ 2.45 MiB/13.40 MiB
# wandb      ------------------------------ 4.40 MiB/21.79 MiB
# inspect-ai ------------------------------ 2.97 MiB/32.96 MiB
# Building transformers-stream-generator==0.0.5
# ⠧ Preparing packages... (48/55)
# pydeck     ------------------------------ 4.64 MiB/6.58 MiB
# streamlit  ------------------------------ 3.76 MiB/8.69 MiB
# botocore   ------------------------------ 2.54 MiB/13.40 MiB
# wandb      ------------------------------ 4.79 MiB/21.79 MiB
# inspect-ai ------------------------------ 2.97 MiB/32.96 MiB
# Building transformers-stream-generator==0.0.5
# ⠇ Preparing packages... (48/55)
# pydeck     ------------------------------ 5.08 MiB/6.58 MiB
# streamlit  ------------------------------ 4.03 MiB/8.69 MiB
# botocore   ------------------------------ 2.56 MiB/13.40 MiB
# wandb      ------------------------------ 5.22 MiB/21.79 MiB
# inspect-ai ------------------------------ 2.97 MiB/32.96 MiB
# Building transformers-stream-generator==0.0.5
# ⠇ Preparing packages... (48/55)
# pydeck     ------------------------------ 5.08 MiB/6.58 MiB
# streamlit  ------------------------------ 4.03 MiB/8.69 MiB
# botocore   ------------------------------ 2.56 MiB/13.40 MiB
# wandb      ------------------------------ 5.22 MiB/21.79 MiB
# inspect-ai ------------------------------ 2.97 MiB/32.96 MiB
# Building transformers-stream-generator==0.0.5
# ⠇ Preparing packages... (48/55)
# pydeck     ------------------------------ 5.25 MiB/6.58 MiB
# streamlit  ------------------------------ 4.18 MiB/8.69 MiB
# botocore   ------------------------------ 2.56 MiB/13.40 MiB
# wandb      ------------------------------ 5.46 MiB/21.79 MiB
# inspect-ai ------------------------------ 2.99 MiB/32.96 MiB
# Building transformers-stream-generator==0.0.5
# ⠇ Preparing packages... (48/55)
# pydeck     ------------------------------ 5.73 MiB/6.58 MiB
# streamlit  ------------------------------ 4.79 MiB/8.69 MiB
# botocore   ------------------------------ 2.59 MiB/13.40 MiB
# wandb      ------------------------------ 5.88 MiB/21.79 MiB
# inspect-ai ------------------------------ 2.99 MiB/32.96 MiB
# Building transformers-stream-generator==0.0.5
# ⠇ Preparing packages... (48/55)
# pydeck     ------------------------------ 6.25 MiB/6.58 MiB
# streamlit  ------------------------------ 5.34 MiB/8.69 MiB
# botocore   ------------------------------ 2.63 MiB/13.40 MiB
# wandb      ------------------------------ 6.47 MiB/21.79 MiB
# inspect-ai ------------------------------ 3.00 MiB/32.96 MiB
# Building transformers-stream-generator==0.0.5
# ⠇ Preparing packages... (48/55)
# streamlit  ------------------------------ 5.51 MiB/8.69 MiB
# botocore   ------------------------------ 2.70 MiB/13.40 MiB
# wandb      ------------------------------ 7.08 MiB/21.79 MiB
# inspect-ai ------------------------------ 3.00 MiB/32.96 MiB
# Building transformers-stream-generator==0.0.5
# ⠇ Preparing packages... (48/55)
# streamlit  ------------------------------ 5.53 MiB/8.69 MiB
# botocore   ------------------------------ 2.72 MiB/13.40 MiB
# wandb      ------------------------------ 7.23 MiB/21.79 MiB
# inspect-ai ------------------------------ 3.01 MiB/32.96 MiB
# Building transformers-stream-generator==0.0.5
# ⠋ Preparing packages... (49/55)
# streamlit  ------------------------------ 5.97 MiB/8.69 MiB
# botocore   ------------------------------ 2.93 MiB/13.40 MiB
# wandb      ------------------------------ 7.75 MiB/21.79 MiB
# inspect-ai ------------------------------ 3.04 MiB/32.96 MiB
# Building transformers-stream-generator==0.0.5
# ⠋ Preparing packages... (49/55)
# streamlit  ------------------------------ 6.47 MiB/8.69 MiB
# botocore   ------------------------------ 3.18 MiB/13.40 MiB
# wandb      ------------------------------ 8.39 MiB/21.79 MiB
# inspect-ai ------------------------------ 3.08 MiB/32.96 MiB
# Building transformers-stream-generator==0.0.5
# ⠋ Preparing packages... (49/55)
# streamlit  ------------------------------ 7.73 MiB/8.69 MiB
# botocore   ------------------------------ 3.41 MiB/13.40 MiB
# wandb      ------------------------------ 9.25 MiB/21.79 MiB
# inspect-ai ------------------------------ 3.09 MiB/32.96 MiB
# Building transformers-stream-generator==0.0.5
# ⠋ Preparing packages... (49/55)
# streamlit  ------------------------------ 8.47 MiB/8.69 MiB
# botocore   ------------------------------ 3.46 MiB/13.40 MiB
# wandb      ------------------------------ 10.19 MiB/21.79 MiB
# inspect-ai ------------------------------ 3.12 MiB/32.96 MiB
# Building transformers-stream-generator==0.0.5
# ⠙ Preparing packages... (49/55)
# streamlit  ------------------------------ 8.51 MiB/8.69 MiB
# botocore   ------------------------------ 3.52 MiB/13.40 MiB
# wandb      ------------------------------ 11.37 MiB/21.79 MiB
# inspect-ai ------------------------------ 3.14 MiB/32.96 MiB
# Building transformers-stream-generator==0.0.5
# ⠙ Preparing packages... (49/55)
# streamlit  ------------------------------ 8.56 MiB/8.69 MiB
# botocore   ------------------------------ 3.57 MiB/13.40 MiB
# wandb      ------------------------------ 12.51 MiB/21.79 MiB
# inspect-ai ------------------------------ 3.15 MiB/32.96 MiB
# Building transformers-stream-generator==0.0.5
# ⠙ Preparing packages... (49/55)
# streamlit  ------------------------------ 8.61 MiB/8.69 MiB
# botocore   ------------------------------ 3.71 MiB/13.40 MiB
# wandb      ------------------------------ 13.55 MiB/21.79 MiB
# inspect-ai ------------------------------ 3.17 MiB/32.96 MiB
# Building transformers-stream-generator==0.0.5
# ⠙ Preparing packages... (49/55)
# botocore   ------------------------------ 3.77 MiB/13.40 MiB
# wandb      ------------------------------ 13.55 MiB/21.79 MiB
# inspect-ai ------------------------------ 3.20 MiB/32.96 MiB
# Building transformers-stream-generator==0.0.5
# ⠙ Preparing packages... (49/55)
# botocore   ------------------------------ 3.86 MiB/13.40 MiB
# wandb      ------------------------------ 14.47 MiB/21.79 MiB
# inspect-ai ------------------------------ 3.23 MiB/32.96 MiB
# Building transformers-stream-generator==0.0.5
# ⠹ Preparing packages... (50/55)
# botocore   ------------------------------ 4.03 MiB/13.40 MiB
# wandb      ------------------------------ 15.31 MiB/21.79 MiB
# inspect-ai ------------------------------ 3.25 MiB/32.96 MiB
# Building transformers-stream-generator==0.0.5
# ⠹ Preparing packages... (50/55)
# botocore   ------------------------------ 4.08 MiB/13.40 MiB
# wandb      ------------------------------ 16.59 MiB/21.79 MiB
# inspect-ai ------------------------------ 3.28 MiB/32.96 MiB
# Building transformers-stream-generator==0.0.5
# ⠹ Preparing packages... (50/55)
# botocore   ------------------------------ 4.18 MiB/13.40 MiB
# wandb      ------------------------------ 17.80 MiB/21.79 MiB
# inspect-ai ------------------------------ 5.03 MiB/32.96 MiB
# Building transformers-stream-generator==0.0.5
# ⠹ Preparing packages... (50/55)
# botocore   ------------------------------ 4.18 MiB/13.40 MiB
# wandb      ------------------------------ 18.97 MiB/21.79 MiB
# inspect-ai ------------------------------ 6.09 MiB/32.96 MiB
# Building transformers-stream-generator==0.0.5
# ⠸ Preparing packages... (50/55)
# botocore   ------------------------------ 4.26 MiB/13.40 MiB
# wandb      ------------------------------ 19.81 MiB/21.79 MiB
# inspect-ai ------------------------------ 7.25 MiB/32.96 MiB
# Building transformers-stream-generator==0.0.5
# ⠸ Preparing packages... (50/55)
# botocore   ------------------------------ 4.33 MiB/13.40 MiB
# wandb      ------------------------------ 19.81 MiB/21.79 MiB
# inspect-ai ------------------------------ 8.12 MiB/32.96 MiB
#    Built transformers-stream-generator==0.0.5
# ⠸ Preparing packages... (50/55)
# botocore   ------------------------------ 4.33 MiB/13.40 MiB
# wandb      ------------------------------ 19.84 MiB/21.79 MiB
# inspect-ai ------------------------------ 8.30 MiB/32.96 MiB
# ⠸ Preparing packages... (50/55)
# botocore   ------------------------------ 4.41 MiB/13.40 MiB
# wandb      ------------------------------ 19.84 MiB/21.79 MiB
# inspect-ai ------------------------------ 8.77 MiB/32.96 MiB
# ⠸ Preparing packages... (50/55)
# botocore   ------------------------------ 5.18 MiB/13.40 MiB
# wandb      ------------------------------ 19.88 MiB/21.79 MiB
# inspect-ai ------------------------------ 9.97 MiB/32.96 MiB
# ⠼ Preparing packages... (51/55)
# botocore   ------------------------------ 5.57 MiB/13.40 MiB
# wandb      ------------------------------ 19.94 MiB/21.79 MiB
# inspect-ai ------------------------------ 10.86 MiB/32.96 MiB
# ⠼ Preparing packages... (51/55)
# botocore   ------------------------------ 5.74 MiB/13.40 MiB
# wandb      ------------------------------ 19.95 MiB/21.79 MiB
# inspect-ai ------------------------------ 12.17 MiB/32.96 MiB
# ⠼ Preparing packages... (51/55)
# botocore   ------------------------------ 5.81 MiB/13.40 MiB
# wandb      ------------------------------ 19.97 MiB/21.79 MiB
# inspect-ai ------------------------------ 13.44 MiB/32.96 MiB
# ⠼ Preparing packages... (51/55)
# botocore   ------------------------------ 6.02 MiB/13.40 MiB
# wandb      ------------------------------ 20.02 MiB/21.79 MiB
# inspect-ai ------------------------------ 14.83 MiB/32.96 MiB
# ⠴ Preparing packages... (51/55)
# botocore   ------------------------------ 6.14 MiB/13.40 MiB
# wandb      ------------------------------ 20.09 MiB/21.79 MiB
# inspect-ai ------------------------------ 16.59 MiB/32.96 MiB
# ⠴ Preparing packages... (51/55)
# botocore   ------------------------------ 6.36 MiB/13.40 MiB
# wandb      ------------------------------ 20.19 MiB/21.79 MiB
# inspect-ai ------------------------------ 17.92 MiB/32.96 MiB
# ⠴ Preparing packages... (51/55)
# botocore   ------------------------------ 6.48 MiB/13.40 MiB
# wandb      ------------------------------ 20.23 MiB/21.79 MiB
# inspect-ai ------------------------------ 19.67 MiB/32.96 MiB
# ⠴ Preparing packages... (51/55)
# botocore   ------------------------------ 6.50 MiB/13.40 MiB
# wandb      ------------------------------ 20.25 MiB/21.79 MiB
# inspect-ai ------------------------------ 20.75 MiB/32.96 MiB
# ⠦ Preparing packages... (51/55)
# botocore   ------------------------------ 6.70 MiB/13.40 MiB
# wandb      ------------------------------ 20.25 MiB/21.79 MiB
# inspect-ai ------------------------------ 22.38 MiB/32.96 MiB
# ⠦ Preparing packages... (51/55)
# botocore   ------------------------------ 6.81 MiB/13.40 MiB
# wandb      ------------------------------ 20.27 MiB/21.79 MiB
# inspect-ai ------------------------------ 23.86 MiB/32.96 MiB
# ⠦ Preparing packages... (51/55)
# botocore   ------------------------------ 6.90 MiB/13.40 MiB
# wandb      ------------------------------ 20.27 MiB/21.79 MiB
# inspect-ai ------------------------------ 25.62 MiB/32.96 MiB
# ⠦ Preparing packages... (51/55)
# botocore   ------------------------------ 6.96 MiB/13.40 MiB
# wandb      ------------------------------ 20.28 MiB/21.79 MiB
# inspect-ai ------------------------------ 26.87 MiB/32.96 MiB
# ⠧ Preparing packages... (51/55)
# botocore   ------------------------------ 7.22 MiB/13.40 MiB
# wandb      ------------------------------ 20.38 MiB/21.79 MiB
# inspect-ai ------------------------------ 28.72 MiB/32.96 MiB
# ⠧ Preparing packages... (51/55)
# botocore   ------------------------------ 7.44 MiB/13.40 MiB
# wandb      ------------------------------ 20.53 MiB/21.79 MiB
# inspect-ai ------------------------------ 29.80 MiB/32.96 MiB
# ⠧ Preparing packages... (51/55)
# botocore   ------------------------------ 7.72 MiB/13.40 MiB
# wandb      ------------------------------ 20.66 MiB/21.79 MiB
# inspect-ai ------------------------------ 30.49 MiB/32.96 MiB
# ⠧ Preparing packages... (51/55)
# botocore   ------------------------------ 8.26 MiB/13.40 MiB
# wandb      ------------------------------ 20.72 MiB/21.79 MiB
# inspect-ai ------------------------------ 31.64 MiB/32.96 MiB
# ⠇ Preparing packages... (51/55)
# botocore   ------------------------------ 8.55 MiB/13.40 MiB
# wandb      ------------------------------ 20.78 MiB/21.79 MiB
# inspect-ai ------------------------------ 32.34 MiB/32.96 MiB
# ⠇ Preparing packages... (51/55)
# botocore   ------------------------------ 8.96 MiB/13.40 MiB
# wandb      ------------------------------ 20.89 MiB/21.79 MiB
# inspect-ai ------------------------------ 32.48 MiB/32.96 MiB
# ⠇ Preparing packages... (51/55)
# botocore   ------------------------------ 9.24 MiB/13.40 MiB
# wandb      ------------------------------ 21.20 MiB/21.79 MiB
# inspect-ai ------------------------------ 32.64 MiB/32.96 MiB
# ⠇ Preparing packages... (51/55)
# botocore   ------------------------------ 9.56 MiB/13.40 MiB
# wandb      ------------------------------ 21.52 MiB/21.79 MiB
# inspect-ai ------------------------------ 32.73 MiB/32.96 MiB
# ⠋ Preparing packages... (51/55)
# botocore   ------------------------------ 9.85 MiB/13.40 MiB
# wandb      ------------------------------ 21.64 MiB/21.79 MiB
# inspect-ai ------------------------------ 32.83 MiB/32.96 MiB
# ⠋ Preparing packages... (51/55)
# botocore   ------------------------------ 9.86 MiB/13.40 MiB
# wandb      ------------------------------ 21.66 MiB/21.79 MiB
# ⠋ Preparing packages... (51/55)
# botocore   ------------------------------ 10.18 MiB/13.40 MiB
# ⠋ Preparing packages... (51/55)
# botocore   ------------------------------ 10.58 MiB/13.40 MiB
# ⠋ Preparing packages... (51/55)
# ⠋ Preparing packages... (51/55)
# ⠋ Preparing packages... (51/55)
# Prepared 55 packages in 3.64s
# Uninstalled 5 packages in 1.01s
# Installed 55 packages in 744ms
#  + aioboto3==15.5.0
#  + aiobotocore==2.25.1
#  + aioitertools==0.13.0
#  + beartype==0.14.1
#  + better-abc==0.0.3
#  + blinker==1.9.0
#  - boto3==1.40.23
#  + boto3==1.40.61
#  - botocore==1.40.23
#  + botocore==1.40.61
#  + cachetools==6.2.4
#  + datasets==4.5.0
#  + dill==0.4.0
#  + docstring-parser==0.17.0
#  + einops==0.8.1
#  + fancy-einsum==0.0.3
#  + frozendict==2.4.7
#  - fsspec==2024.6.1
#  + fsspec==2025.9.0
#  + gitdb==4.0.12
#  + gitpython==3.1.46
#  + ijson==3.4.0.post0
#  + inspect-ai==0.3.163
#  + jaxtyping==0.3.5
#  + jsonlines==4.0.0
#  + jsonpatch==1.33
#  + jsonpath-ng==1.7.0
#  + jsonpointer==3.0.0
#  + jsonref==1.1.0
#  + linkify-it-py==2.0.3
#  + mdit-py-plugins==0.5.0
#  + mmh3==5.2.0
#  + multiprocess==0.70.18
#  + nest-asyncio2==1.7.1
#  + pathlib-abc==0.5.2
#  + ply==3.11
#  + pyarrow==23.0.0
#  + pydeck==0.9.1
#  - rich==14.1.0
#  + rich==14.2.0
#  + s3fs==2025.9.0
#  - s3transfer==0.13.1
#  + s3transfer==0.14.0
#  + semver==3.0.4
#  + sentry-sdk==2.50.0
#  + shortuuid==1.0.13
#  + smmap==5.0.2
#  + streamlit==1.53.1
#  + tenacity==9.1.2
#  + textual==7.3.0
#  + tiktoken==0.12.0
#  + transformer-lens==2.15.4
#  + transformers-stream-generator==0.0.5
#  + typeguard==4.4.2
#  + uc-micro-py==1.0.3
#  + universal-pathlib==0.3.8
#  + wadler-lindig==0.1.7
#  + wandb==0.24.0
#  + watchdog==6.0.0
#  + xxhash==3.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import modal
modal.enable_output()
print("Live streaming enabled — all remote prints will appear in real time!")
# Out:
# Live streaming enabled — all remote prints will appear in real time!

# %%
# %uv pip install inspect-ai transformer-lens torch accelerate bitsandbytes

# suppress tokenizers fork warning
import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"

import time
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM
from transformer_lens import HookedTransformer
import numpy as np

print("\n" + "="*100)
print("FINAL SENTINEL PRE-FLIGHT CHECKLIST – ALL STEPS COMPLETE")
print("Model: gpt2 (pre-flight baseline – ready for Llama-3-8B)")
print("All 4 steps done: installs, model load, activations, latency timer")
print("="*100 + "\n")

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Device: {device}")
if device == 'cuda':
    for i in range(torch.cuda.device_count()):
        print(f"GPU {i}: {torch.cuda.get_device_name(i)}")
        print(f"VRAM {i}: {torch.cuda.get_device_properties(i).total_memory / 1e9:.1f} GB")

print("\n[✓] STEP 1: Installs already handled via %uv pip (inspect-ai + transformer-lens + torch)")

print("\n[✓] STEP 2: Loading tokenizer...")
model_name = "gpt2"  # swap to "meta-llama/Llama-3-8B-Instruct" later with token
tokenizer = AutoTokenizer.from_pretrained(model_name)
print("Tokenizer loaded ✓")

print("\n[✓] STEP 2 cont: Loading base model in FP16...")
hf_model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="cuda" if device == 'cuda' else "cpu",
    torch_dtype=torch.float16,
    low_cpu_mem_usage=True
)
hf_model = hf_model.to(device)
print("Base model loaded ✓")

print("\n[✓] STEP 3: Wrapping with TransformerLens – Hello World activations...")
hooked_model = HookedTransformer.from_pretrained(
    model_name,
    hf_model=hf_model,
    tokenizer=tokenizer,
    device=device,
    dtype=torch.float16,
    move_to_device=True,
    fold_ln=False,
    center_writing_weights=False,
    center_unembed=False,
    fold_value_biases=False
)
print(f"Hooked model ready – {hooked_model.cfg.n_layers} layers ✓")

print("\nHello World prompt for activations...")
prompt = "Hello world, testing sentinel pre-flight activations for safety tax trilemma."
print(f"Prompt: '{prompt}'")
tokens = tokenizer(prompt, return_tensors="pt").to(device)

print("Running with cache to get activations...")
_, cache = hooked_model.run_with_cache(tokens['input_ids'])
sample_act = cache['blocks.0.hook_resid_post'][0, -1, :5].cpu().numpy()
print(f"Sample activations (blocks.0 resid post, last token first 5): {sample_act} ✓")
print("Hello World activations success – TransformerLens working ✓")

print("\n[✓] STEP 4: Latency timer (simple forward pass – sufficient for pre-flight)...")
torch.cuda.reset_peak_memory_stats() if torch.cuda.is_available() else None
start_time = time.time()
_ = hooked_model(tokens['input_ids'])  # full forward pass
end_time = time.time()
latency_ms = (end_time - start_time) * 1000
vram_peak = torch.cuda.max_memory_allocated() / 1e9 if torch.cuda.is_available() else 0
print(f"Forward pass latency: {latency_ms:.2f} ms ✓")
print(f"Peak VRAM used: {vram_peak:.2f} GB ✓")
print("Latency timer working – ready for paper data ✓")

print("\n" + "="*100)
print("PRE-FLIGHT CHECKLIST 100% COMPLETE – ALL 4 STEPS DONE")
print("• Installs verified")
print("• gpt2 model loaded successfully")
print("• TransformerLens activations output for 1 prompt")
print("• Latency captured with time.time() – inspect-ai skipped (not required for pre-flight)")
print("Unblocked for full sentinel interceptor build")
print("Next: add real hooks (layers 10-12 scan/block), Llama-3-8B swap, dataset contrasts")
print("="*100)
# Out:
# Using Python 3.12.6 environment at: /usr/local
# Audited 5 packages in 27ms
# Note: you may need to restart the kernel to use updated packages.
#
# ====================================================================================================
# FINAL SENTINEL PRE-FLIGHT CHECKLIST – ALL STEPS COMPLETE
# Model: gpt2 (pre-flight baseline – ready for Llama-3-8B)
# All 4 steps done: installs, model load, activations, latency timer
# ====================================================================================================
#
# Device: cuda
# GPU 0: NVIDIA A100-SXM4-40GB
# VRAM 0: 42.4 GB
#
# [✓] STEP 1: Installs already handled via %uv pip (inspect-ai + transformer-lens + torch)
#
# [✓] STEP 2: Loading tokenizer...
# Tokenizer loaded ✓
#
# [✓] STEP 2 cont: Loading base model in FP16...
# Base model loaded ✓
#
# [✓] STEP 3: Wrapping with TransformerLens – Hello World activations...
# Loaded pretrained model gpt2 into HookedTransformer
# Hooked model ready – 12 layers ✓
#
# Hello World prompt for activations...
# Prompt: 'Hello world, testing sentinel pre-flight activations for safety tax trilemma.'
# Running with cache to get activations...
# Sample activations (blocks.0 resid post, last token first 5): [ 1.087  -0.1166 -0.2942  0.776  -0.1304] ✓
# Hello World activations success – TransformerLens working ✓
#
# [✓] STEP 4: Latency timer (simple forward pass – sufficient for pre-flight)...
# Forward pass latency: 26.18 ms ✓
# Peak VRAM used: 1.09 GB ✓
# Latency timer working – ready for paper data ✓
#
# ====================================================================================================
# PRE-FLIGHT CHECKLIST 100% COMPLETE – ALL 4 STEPS DONE
# • Installs verified
# • gpt2 model loaded successfully
# • TransformerLens activations output for 1 prompt
# • Latency captured with time.time() – inspect-ai skipped (not required for pre-flight)
# Unblocked for full sentinel interceptor build
# Next: add real hooks (layers 10-12 scan/block), Llama-3-8B swap, dataset contrasts
# ====================================================================================================

# %%
# %uv pip install transformers torch transformer-lens accelerate bitsandbytes

# suppress tokenizers warning
import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"

import time
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
from transformer_lens import HookedTransformer
import numpy as np

print("\n" + "="*100)
print("FINAL SENTINEL FLIGHT CHECK + LLAMA-3 SWAP – 4-BIT NF4 QUANT")
print("Model: NousResearch/Meta-Llama-3-8B-Instruct (public, no gate, tl official)")
print("• 4-bit quant – ~4-6 GB VRAM (home computer proof)")
print("• Activation shape shown")
print("="*100 + "\n")

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Device: {device}")
if device == 'cuda':
    for i in range(torch.cuda.device_count()):
        print(f"GPU {i}: {torch.cuda.get_device_name(i)}")
        print(f"VRAM {i}: {torch.cuda.get_device_properties(i).total_memory / 1e9:.1f} GB")

print("\nSTEP 1: Loading tokenizer...")
model_name = "meta-llama/Llama-3.1-8B"
tokenizer = AutoTokenizer.from_pretrained(model_name)
print("Tokenizer loaded ✓")

print("\nSTEP 2: Loading base model in 4-bit NF4 quant...")
quant_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_use_double_quant=True
)

hf_model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=quant_config,
    device_map="auto",
    low_cpu_mem_usage=True,
    trust_remote_code=True
)
print("Base model loaded in 4-bit – home computer fit ✓")

print("\nSTEP 3: Wrapping with TransformerLens...")
hooked_model = HookedTransformer.from_pretrained(
    model_name,
    hf_model=hf_model,
    tokenizer=tokenizer,
    device=device,
    dtype=torch.float16,
    move_to_device=True,
    fold_ln=False,
    center_writing_weights=False,
    center_unembed=False,
    fold_value_biases=False
)
print(f"Hooked model ready – {hooked_model.cfg.n_layers} layers ✓")

print("\nLlama-3-8B-Instruct (4-bit) loaded ✓ – testing activations...")

prompt = "Hello world, testing sentinel pre-flight activations on Llama-3 for safety tax trilemma."
print(f"\nTest prompt: '{prompt}'")
tokens = tokenizer(prompt, return_tensors="pt").to(device)

print("Running with cache to get activations...")
torch.cuda.reset_peak_memory_stats() if torch.cuda.is_available() else None
start_time = time.time()
_, cache = hooked_model.run_with_cache(tokens['input_ids'])
end_time = time.time()
latency_ms = (end_time - start_time) * 1000
vram_peak = torch.cuda.max_memory_allocated() / 1e9 if torch.cuda.is_available() else 0

act_shape = cache['blocks.0.hook_resid_post'].shape
print(f"Activation shape (blocks.0 resid post): {act_shape} ✓ (batch, seq_len, hidden_size)")
print(f"Latency: {latency_ms:.2f} ms ✓")
print(f"Peak VRAM: {vram_peak:.2f} GB ✓ – fits home computer w 4-bit quant")

print("\n" + "="*100)
print("LLAMA-3 SWAP COMPLETE – 4-BIT SUCCESS")
print("• Public model, no gate")
print("• Quant proven")
print("• Activation shape shown")
print("Ready for sentinel hooks (layers 10-12 scan/block)")
print("="*100)
# Out:
# Using Python 3.12.6 environment at: /usr/local
# Resolved 91 packages in 365ms
# Building transformers-stream-generator==0.0.5
# Building transformers-stream-generator==0.0.5
# ⠙ Preparing packages... (0/21)
# Building transformers-stream-generator==0.0.5
# ⠙ Preparing packages... (0/21)
# Building transformers-stream-generator==0.0.5
# ⠙ Preparing packages... (0/21)
# wadler-lindig ------------------------------ 14.94 KiB/20.04 KiB
# Building transformers-stream-generator==0.0.5
# ⠙ Preparing packages... (0/21)
# wadler-lindig ------------------------------ 14.94 KiB/20.04 KiB
# smmap      ------------------------------     0 B/23.73 KiB
# Building transformers-stream-generator==0.0.5
# ⠙ Preparing packages... (0/21)
# wadler-lindig ------------------------------ 14.94 KiB/20.04 KiB
# smmap      ------------------------------ 14.95 KiB/23.73 KiB
# Building transformers-stream-generator==0.0.5
# ⠙ Preparing packages... (0/21)
# wadler-lindig ------------------------------ 14.94 KiB/20.04 KiB
# smmap      ------------------------------ 14.95 KiB/23.73 KiB
# gitdb      ------------------------------     0 B/61.32 KiB
# Building transformers-stream-generator==0.0.5
# ⠙ Preparing packages... (0/21)
# wadler-lindig ------------------------------ 14.94 KiB/20.04 KiB
# smmap      ------------------------------ 14.95 KiB/23.73 KiB
# gitdb      ------------------------------ 14.95 KiB/61.32 KiB
# Building transformers-stream-generator==0.0.5
# ⠙ Preparing packages... (0/21)
# wadler-lindig ------------------------------ 14.94 KiB/20.04 KiB
# smmap      ------------------------------ 14.95 KiB/23.73 KiB
# gitdb      ------------------------------ 14.95 KiB/61.32 KiB
# dill       ------------------------------     0 B/116.86 KiB
# Building transformers-stream-generator==0.0.5
# ⠙ Preparing packages... (0/21)
# wadler-lindig ------------------------------ 14.94 KiB/20.04 KiB
# smmap      ------------------------------ 14.95 KiB/23.73 KiB
# gitdb      ------------------------------ 14.95 KiB/61.32 KiB
# dill       ------------------------------ 16.00 KiB/116.86 KiB
# Building transformers-stream-generator==0.0.5
# ⠙ Preparing packages... (0/21)
# wadler-lindig ------------------------------ 14.94 KiB/20.04 KiB
# smmap      ------------------------------ 14.95 KiB/23.73 KiB
# gitdb      ------------------------------ 14.95 KiB/61.32 KiB
# dill       ------------------------------ 16.00 KiB/116.86 KiB
# Building transformers-stream-generator==0.0.5
# ⠙ Preparing packages... (0/21)
# wadler-lindig ------------------------------ 14.94 KiB/20.04 KiB
# smmap      ------------------------------ 14.95 KiB/23.73 KiB
# gitdb      ------------------------------ 14.95 KiB/61.32 KiB
# dill       ------------------------------ 16.00 KiB/116.86 KiB
# transformer-lens ------------------------------ 16.00 KiB/190.61 KiB
# Building transformers-stream-generator==0.0.5
# ⠙ Preparing packages... (0/21)
# wadler-lindig ------------------------------ 14.94 KiB/20.04 KiB
# smmap      ------------------------------ 14.95 KiB/23.73 KiB
# gitdb      ------------------------------ 14.95 KiB/61.32 KiB
# dill       ------------------------------ 16.00 KiB/116.86 KiB
# transformer-lens ------------------------------ 16.00 KiB/190.61 KiB
# Building transformers-stream-generator==0.0.5
# ⠙ Preparing packages... (0/21)
# wadler-lindig ------------------------------ 14.94 KiB/20.04 KiB
# smmap      ------------------------------ 14.95 KiB/23.73 KiB
# gitdb      ------------------------------ 14.95 KiB/61.32 KiB
# einops     ------------------------------     0 B/62.85 KiB
# dill       ------------------------------ 16.00 KiB/116.86 KiB
# transformer-lens ------------------------------ 16.00 KiB/190.61 KiB
# Building transformers-stream-generator==0.0.5
# ⠙ Preparing packages... (0/21)
# wadler-lindig ------------------------------ 14.94 KiB/20.04 KiB
# smmap      ------------------------------ 14.95 KiB/23.73 KiB
# gitdb      ------------------------------ 14.95 KiB/61.32 KiB
# einops     ------------------------------ 14.92 KiB/62.85 KiB
# dill       ------------------------------ 16.00 KiB/116.86 KiB
# transformer-lens ------------------------------ 16.00 KiB/190.61 KiB
# Building transformers-stream-generator==0.0.5
# ⠙ Preparing packages... (0/21)
# wadler-lindig ------------------------------ 14.94 KiB/20.04 KiB
# smmap      ------------------------------ 14.95 KiB/23.73 KiB
# typeguard  ------------------------------     0 B/34.96 KiB
# gitdb      ------------------------------ 14.95 KiB/61.32 KiB
# einops     ------------------------------ 14.92 KiB/62.85 KiB
# dill       ------------------------------ 16.00 KiB/116.86 KiB
# transformer-lens ------------------------------ 16.00 KiB/190.61 KiB
# Building transformers-stream-generator==0.0.5
# ⠙ Preparing packages... (0/21)
# wadler-lindig ------------------------------ 14.94 KiB/20.04 KiB
# smmap      ------------------------------ 14.95 KiB/23.73 KiB
# typeguard  ------------------------------ 14.95 KiB/34.96 KiB
# gitdb      ------------------------------ 14.95 KiB/61.32 KiB
# einops     ------------------------------ 14.92 KiB/62.85 KiB
# dill       ------------------------------ 16.00 KiB/116.86 KiB
# transformer-lens ------------------------------ 16.00 KiB/190.61 KiB
# Building transformers-stream-generator==0.0.5
# ⠙ Preparing packages... (0/21)
# better-abc ------------------------------ 3.39 KiB/3.39 KiB
# fancy-einsum ------------------------------ 6.09 KiB/6.09 KiB
# wadler-lindig ------------------------------ 14.94 KiB/20.04 KiB
# smmap      ------------------------------ 14.95 KiB/23.73 KiB
# typeguard  ------------------------------ 14.95 KiB/34.96 KiB
# jaxtyping  ------------------------------ 16.00 KiB/54.52 KiB
# gitdb      ------------------------------ 14.95 KiB/61.32 KiB
# einops     ------------------------------ 14.92 KiB/62.85 KiB
# dill       ------------------------------ 32.00 KiB/116.86 KiB
# multiprocess ------------------------------ 14.94 KiB/146.76 KiB
# xxhash     ------------------------------ 16.00 KiB/189.34 KiB
# transformer-lens ------------------------------ 32.00 KiB/190.61 KiB
# gitpython  ------------------------------ 31.89 KiB/203.73 KiB
# sentry-sdk ------------------------------ 16.00 KiB/415.00 KiB
# datasets   ------------------------------ 32.00 KiB/503.12 KiB
# beartype   ------------------------------ 14.95 KiB/722.40 KiB
# numpy      ------------------------------ 16.00 KiB/17.12 MiB
# wandb      ------------------------------ 16.00 KiB/21.79 MiB
# pyarrow    ------------------------------ 14.94 KiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠙ Preparing packages... (0/21)
# better-abc ------------------------------ 3.39 KiB/3.39 KiB
# fancy-einsum ------------------------------ 6.09 KiB/6.09 KiB
# smmap      ------------------------------ 23.73 KiB/23.73 KiB
# typeguard  ------------------------------ 30.95 KiB/34.96 KiB
# jaxtyping  ------------------------------ 32.00 KiB/54.52 KiB
# gitdb      ------------------------------ 46.95 KiB/61.32 KiB
# einops     ------------------------------ 30.92 KiB/62.85 KiB
# dill       ------------------------------ 48.00 KiB/116.86 KiB
# multiprocess ------------------------------ 19.48 KiB/146.76 KiB
# xxhash     ------------------------------ 189.34 KiB/189.34 KiB
# transformer-lens ------------------------------ 79.89 KiB/190.61 KiB
# gitpython  ------------------------------ 47.89 KiB/203.73 KiB
# sentry-sdk ------------------------------ 16.00 KiB/415.00 KiB
# datasets   ------------------------------ 111.89 KiB/503.12 KiB
# beartype   ------------------------------ 46.95 KiB/722.40 KiB
# numpy      ------------------------------ 16.00 KiB/17.12 MiB
# wandb      ------------------------------ 32.00 KiB/21.79 MiB
# pyarrow    ------------------------------ 174.94 KiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠙ Preparing packages... (0/21)
# better-abc ------------------------------ 3.39 KiB/3.39 KiB
# fancy-einsum ------------------------------ 6.09 KiB/6.09 KiB
# smmap      ------------------------------ 23.73 KiB/23.73 KiB
# typeguard  ------------------------------ 30.95 KiB/34.96 KiB
# jaxtyping  ------------------------------ 32.00 KiB/54.52 KiB
# gitdb      ------------------------------ 46.95 KiB/61.32 KiB
# einops     ------------------------------ 30.92 KiB/62.85 KiB
# dill       ------------------------------ 48.00 KiB/116.86 KiB
# multiprocess ------------------------------ 35.48 KiB/146.76 KiB
# xxhash     ------------------------------ 189.34 KiB/189.34 KiB
# transformer-lens ------------------------------ 79.89 KiB/190.61 KiB
# gitpython  ------------------------------ 60.19 KiB/203.73 KiB
# sentry-sdk ------------------------------ 16.00 KiB/415.00 KiB
# datasets   ------------------------------ 111.89 KiB/503.12 KiB
# beartype   ------------------------------ 46.95 KiB/722.40 KiB
# numpy      ------------------------------ 16.00 KiB/17.12 MiB
# wandb      ------------------------------ 32.00 KiB/21.79 MiB
# pyarrow    ------------------------------ 174.94 KiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠙ Preparing packages... (0/21)
# fancy-einsum ------------------------------ 6.09 KiB/6.09 KiB
# smmap      ------------------------------ 23.73 KiB/23.73 KiB
# typeguard  ------------------------------ 30.95 KiB/34.96 KiB
# jaxtyping  ------------------------------ 43.48 KiB/54.52 KiB
# gitdb      ------------------------------ 46.95 KiB/61.32 KiB
# einops     ------------------------------ 30.92 KiB/62.85 KiB
# dill       ------------------------------ 64.00 KiB/116.86 KiB
# multiprocess ------------------------------ 51.48 KiB/146.76 KiB
# xxhash     ------------------------------ 189.34 KiB/189.34 KiB
# transformer-lens ------------------------------ 79.89 KiB/190.61 KiB
# gitpython  ------------------------------ 60.19 KiB/203.73 KiB
# sentry-sdk ------------------------------ 16.00 KiB/415.00 KiB
# datasets   ------------------------------ 111.89 KiB/503.12 KiB
# beartype   ------------------------------ 46.95 KiB/722.40 KiB
# numpy      ------------------------------ 16.00 KiB/17.12 MiB
# wandb      ------------------------------ 32.00 KiB/21.79 MiB
# pyarrow    ------------------------------ 568.22 KiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠙ Preparing packages... (0/21)
# smmap      ------------------------------ 23.73 KiB/23.73 KiB
# typeguard  ------------------------------ 30.95 KiB/34.96 KiB
# jaxtyping  ------------------------------ 43.48 KiB/54.52 KiB
# gitdb      ------------------------------ 46.95 KiB/61.32 KiB
# einops     ------------------------------ 30.92 KiB/62.85 KiB
# dill       ------------------------------ 64.00 KiB/116.86 KiB
# multiprocess ------------------------------ 51.48 KiB/146.76 KiB
# xxhash     ------------------------------ 189.34 KiB/189.34 KiB
# transformer-lens ------------------------------ 79.89 KiB/190.61 KiB
# gitpython  ------------------------------ 76.19 KiB/203.73 KiB
# sentry-sdk ------------------------------ 16.00 KiB/415.00 KiB
# datasets   ------------------------------ 144.00 KiB/503.12 KiB
# beartype   ------------------------------ 46.95 KiB/722.40 KiB
# numpy      ------------------------------ 16.00 KiB/17.12 MiB
# wandb      ------------------------------ 32.00 KiB/21.79 MiB
# pyarrow    ------------------------------ 568.22 KiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠙ Preparing packages... (0/21)
# smmap      ------------------------------ 23.73 KiB/23.73 KiB
# typeguard  ------------------------------ 30.95 KiB/34.96 KiB
# jaxtyping  ------------------------------ 43.48 KiB/54.52 KiB
# gitdb      ------------------------------ 46.95 KiB/61.32 KiB
# einops     ------------------------------ 30.92 KiB/62.85 KiB
# dill       ------------------------------ 80.00 KiB/116.86 KiB
# multiprocess ------------------------------ 51.48 KiB/146.76 KiB
# transformer-lens ------------------------------ 79.89 KiB/190.61 KiB
# gitpython  ------------------------------ 92.19 KiB/203.73 KiB
# sentry-sdk ------------------------------ 32.00 KiB/415.00 KiB
# datasets   ------------------------------ 144.00 KiB/503.12 KiB
# beartype   ------------------------------ 62.95 KiB/722.40 KiB
# numpy      ------------------------------ 16.00 KiB/17.12 MiB
# wandb      ------------------------------ 32.00 KiB/21.79 MiB
# pyarrow    ------------------------------ 600.56 KiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠙ Preparing packages... (0/21)
# typeguard  ------------------------------ 34.96 KiB/34.96 KiB
# jaxtyping  ------------------------------ 54.52 KiB/54.52 KiB
# gitdb      ------------------------------ 46.95 KiB/61.32 KiB
# einops     ------------------------------ 30.92 KiB/62.85 KiB
# dill       ------------------------------ 80.00 KiB/116.86 KiB
# multiprocess ------------------------------ 51.48 KiB/146.76 KiB
# transformer-lens ------------------------------ 96.00 KiB/190.61 KiB
# gitpython  ------------------------------ 108.19 KiB/203.73 KiB
# sentry-sdk ------------------------------ 48.00 KiB/415.00 KiB
# datasets   ------------------------------ 160.00 KiB/503.12 KiB
# beartype   ------------------------------ 62.95 KiB/722.40 KiB
# numpy      ------------------------------ 16.00 KiB/17.12 MiB
# wandb      ------------------------------ 64.00 KiB/21.79 MiB
# pyarrow    ------------------------------ 728.56 KiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠙ Preparing packages... (0/21)
# typeguard  ------------------------------ 34.96 KiB/34.96 KiB
# jaxtyping  ------------------------------ 54.52 KiB/54.52 KiB
# gitdb      ------------------------------ 46.95 KiB/61.32 KiB
# einops     ------------------------------ 30.92 KiB/62.85 KiB
# dill       ------------------------------ 80.00 KiB/116.86 KiB
# multiprocess ------------------------------ 51.48 KiB/146.76 KiB
# transformer-lens ------------------------------ 96.00 KiB/190.61 KiB
# gitpython  ------------------------------ 108.19 KiB/203.73 KiB
# sentry-sdk ------------------------------ 48.00 KiB/415.00 KiB
# datasets   ------------------------------ 160.00 KiB/503.12 KiB
# beartype   ------------------------------ 62.95 KiB/722.40 KiB
# numpy      ------------------------------ 16.00 KiB/17.12 MiB
# wandb      ------------------------------ 64.00 KiB/21.79 MiB
# pyarrow    ------------------------------ 744.56 KiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠙ Preparing packages... (0/21)
# jaxtyping  ------------------------------ 54.52 KiB/54.52 KiB
# gitdb      ------------------------------ 61.32 KiB/61.32 KiB
# einops     ------------------------------ 46.92 KiB/62.85 KiB
# dill       ------------------------------ 80.00 KiB/116.86 KiB
# multiprocess ------------------------------ 67.48 KiB/146.76 KiB
# transformer-lens ------------------------------ 96.00 KiB/190.61 KiB
# gitpython  ------------------------------ 124.19 KiB/203.73 KiB
# sentry-sdk ------------------------------ 64.00 KiB/415.00 KiB
# datasets   ------------------------------ 208.00 KiB/503.12 KiB
# beartype   ------------------------------ 142.95 KiB/722.40 KiB
# numpy      ------------------------------ 32.00 KiB/17.12 MiB
# wandb      ------------------------------ 64.00 KiB/21.79 MiB
# pyarrow    ------------------------------ 1.05 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠙ Preparing packages... (0/21)
# gitdb      ------------------------------ 61.32 KiB/61.32 KiB
# einops     ------------------------------ 46.92 KiB/62.85 KiB
# dill       ------------------------------ 80.00 KiB/116.86 KiB
# multiprocess ------------------------------ 78.94 KiB/146.76 KiB
# transformer-lens ------------------------------ 96.00 KiB/190.61 KiB
# gitpython  ------------------------------ 124.19 KiB/203.73 KiB
# sentry-sdk ------------------------------ 64.00 KiB/415.00 KiB
# datasets   ------------------------------ 224.00 KiB/503.12 KiB
# beartype   ------------------------------ 142.95 KiB/722.40 KiB
# numpy      ------------------------------ 48.00 KiB/17.12 MiB
# wandb      ------------------------------ 80.00 KiB/21.79 MiB
# pyarrow    ------------------------------ 1.08 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠹ Preparing packages... (7/21)
# gitdb      ------------------------------ 61.32 KiB/61.32 KiB
# einops     ------------------------------ 62.85 KiB/62.85 KiB
# dill       ------------------------------ 96.00 KiB/116.86 KiB
# multiprocess ------------------------------ 94.83 KiB/146.76 KiB
# transformer-lens ------------------------------ 96.00 KiB/190.61 KiB
# gitpython  ------------------------------ 156.19 KiB/203.73 KiB
# sentry-sdk ------------------------------ 80.00 KiB/415.00 KiB
# datasets   ------------------------------ 240.00 KiB/503.12 KiB
# beartype   ------------------------------ 145.66 KiB/722.40 KiB
# numpy      ------------------------------ 64.00 KiB/17.12 MiB
# wandb      ------------------------------ 80.00 KiB/21.79 MiB
# pyarrow    ------------------------------ 1.25 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠹ Preparing packages... (7/21)
# einops     ------------------------------ 62.85 KiB/62.85 KiB
# dill       ------------------------------ 96.00 KiB/116.86 KiB
# multiprocess ------------------------------ 142.83 KiB/146.76 KiB
# transformer-lens ------------------------------ 112.00 KiB/190.61 KiB
# gitpython  ------------------------------ 156.19 KiB/203.73 KiB
# sentry-sdk ------------------------------ 112.00 KiB/415.00 KiB
# datasets   ------------------------------ 240.00 KiB/503.12 KiB
# beartype   ------------------------------ 161.66 KiB/722.40 KiB
# numpy      ------------------------------ 80.00 KiB/17.12 MiB
# wandb      ------------------------------ 80.00 KiB/21.79 MiB
# pyarrow    ------------------------------ 1.33 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠹ Preparing packages... (7/21)
# dill       ------------------------------ 96.00 KiB/116.86 KiB
# multiprocess ------------------------------ 142.83 KiB/146.76 KiB
# transformer-lens ------------------------------ 112.00 KiB/190.61 KiB
# gitpython  ------------------------------ 172.19 KiB/203.73 KiB
# sentry-sdk ------------------------------ 112.00 KiB/415.00 KiB
# datasets   ------------------------------ 256.00 KiB/503.12 KiB
# beartype   ------------------------------ 161.66 KiB/722.40 KiB
# numpy      ------------------------------ 80.00 KiB/17.12 MiB
# wandb      ------------------------------ 80.00 KiB/21.79 MiB
# pyarrow    ------------------------------ 1.44 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠹ Preparing packages... (7/21)
# dill       ------------------------------ 112.00 KiB/116.86 KiB
# multiprocess ------------------------------ 142.83 KiB/146.76 KiB
# transformer-lens ------------------------------ 144.00 KiB/190.61 KiB
# gitpython  ------------------------------ 203.73 KiB/203.73 KiB
# sentry-sdk ------------------------------ 144.00 KiB/415.00 KiB
# datasets   ------------------------------ 288.00 KiB/503.12 KiB
# beartype   ------------------------------ 177.66 KiB/722.40 KiB
# numpy      ------------------------------ 96.00 KiB/17.12 MiB
# wandb      ------------------------------ 95.89 KiB/21.79 MiB
# pyarrow    ------------------------------ 1.55 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠹ Preparing packages... (7/21)
# dill       ------------------------------ 112.00 KiB/116.86 KiB
# multiprocess ------------------------------ 142.83 KiB/146.76 KiB
# transformer-lens ------------------------------ 144.00 KiB/190.61 KiB
# sentry-sdk ------------------------------ 160.00 KiB/415.00 KiB
# datasets   ------------------------------ 288.00 KiB/503.12 KiB
# beartype   ------------------------------ 193.66 KiB/722.40 KiB
# numpy      ------------------------------ 96.00 KiB/17.12 MiB
# wandb      ------------------------------ 95.89 KiB/21.79 MiB
# pyarrow    ------------------------------ 1.60 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠹ Preparing packages... (7/21)
# multiprocess ------------------------------ 146.76 KiB/146.76 KiB
# transformer-lens ------------------------------ 160.00 KiB/190.61 KiB
# sentry-sdk ------------------------------ 174.72 KiB/415.00 KiB
# datasets   ------------------------------ 319.89 KiB/503.12 KiB
# beartype   ------------------------------ 222.95 KiB/722.40 KiB
# numpy      ------------------------------ 144.00 KiB/17.12 MiB
# wandb      ------------------------------ 95.89 KiB/21.79 MiB
# pyarrow    ------------------------------ 1.69 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠹ Preparing packages... (7/21)
# transformer-lens ------------------------------ 160.00 KiB/190.61 KiB
# sentry-sdk ------------------------------ 174.72 KiB/415.00 KiB
# datasets   ------------------------------ 319.89 KiB/503.12 KiB
# beartype   ------------------------------ 222.95 KiB/722.40 KiB
# numpy      ------------------------------ 144.00 KiB/17.12 MiB
# wandb      ------------------------------ 95.89 KiB/21.79 MiB
# pyarrow    ------------------------------ 1.69 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠹ Preparing packages... (7/21)
# transformer-lens ------------------------------ 160.00 KiB/190.61 KiB
# sentry-sdk ------------------------------ 190.72 KiB/415.00 KiB
# datasets   ------------------------------ 319.89 KiB/503.12 KiB
# beartype   ------------------------------ 224.16 KiB/722.40 KiB
# numpy      ------------------------------ 176.00 KiB/17.12 MiB
# wandb      ------------------------------ 127.89 KiB/21.79 MiB
# pyarrow    ------------------------------ 1.75 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠹ Preparing packages... (7/21)
# sentry-sdk ------------------------------ 224.00 KiB/415.00 KiB
# datasets   ------------------------------ 336.00 KiB/503.12 KiB
# beartype   ------------------------------ 286.95 KiB/722.40 KiB
# numpy      ------------------------------ 265.81 KiB/17.12 MiB
# wandb      ------------------------------ 176.00 KiB/21.79 MiB
# pyarrow    ------------------------------ 1.86 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠹ Preparing packages... (7/21)
# sentry-sdk ------------------------------ 256.00 KiB/415.00 KiB
# datasets   ------------------------------ 352.00 KiB/503.12 KiB
# beartype   ------------------------------ 318.95 KiB/722.40 KiB
# numpy      ------------------------------ 345.81 KiB/17.12 MiB
# wandb      ------------------------------ 208.00 KiB/21.79 MiB
# pyarrow    ------------------------------ 1.98 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠹ Preparing packages... (7/21)
# sentry-sdk ------------------------------ 320.00 KiB/415.00 KiB
# datasets   ------------------------------ 400.00 KiB/503.12 KiB
# beartype   ------------------------------ 382.95 KiB/722.40 KiB
# numpy      ------------------------------ 490.22 KiB/17.12 MiB
# wandb      ------------------------------ 617.43 KiB/21.79 MiB
# pyarrow    ------------------------------ 2.18 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠸ Preparing packages... (13/21)
# sentry-sdk ------------------------------ 320.00 KiB/415.00 KiB
# datasets   ------------------------------ 400.00 KiB/503.12 KiB
# beartype   ------------------------------ 414.95 KiB/722.40 KiB
# numpy      ------------------------------ 490.22 KiB/17.12 MiB
# wandb      ------------------------------ 2.74 MiB/21.79 MiB
# pyarrow    ------------------------------ 2.34 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠸ Preparing packages... (13/21)
# sentry-sdk ------------------------------ 336.00 KiB/415.00 KiB
# datasets   ------------------------------ 416.00 KiB/503.12 KiB
# beartype   ------------------------------ 430.95 KiB/722.40 KiB
# numpy      ------------------------------ 490.22 KiB/17.12 MiB
# wandb      ------------------------------ 3.78 MiB/21.79 MiB
# pyarrow    ------------------------------ 2.50 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠸ Preparing packages... (13/21)
# sentry-sdk ------------------------------ 352.00 KiB/415.00 KiB
# beartype   ------------------------------ 446.95 KiB/722.40 KiB
# numpy      ------------------------------ 585.81 KiB/17.12 MiB
# wandb      ------------------------------ 4.30 MiB/21.79 MiB
# pyarrow    ------------------------------ 2.71 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠸ Preparing packages... (13/21)
# sentry-sdk ------------------------------ 352.00 KiB/415.00 KiB
# beartype   ------------------------------ 446.95 KiB/722.40 KiB
# numpy      ------------------------------ 585.81 KiB/17.12 MiB
# wandb      ------------------------------ 4.32 MiB/21.79 MiB
# pyarrow    ------------------------------ 2.71 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠸ Preparing packages... (13/21)
# sentry-sdk ------------------------------ 368.00 KiB/415.00 KiB
# beartype   ------------------------------ 494.84 KiB/722.40 KiB
# numpy      ------------------------------ 617.81 KiB/17.12 MiB
# wandb      ------------------------------ 4.65 MiB/21.79 MiB
# pyarrow    ------------------------------ 4.18 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠼ Preparing packages... (14/21)
# sentry-sdk ------------------------------ 368.00 KiB/415.00 KiB
# beartype   ------------------------------ 494.84 KiB/722.40 KiB
# numpy      ------------------------------ 617.81 KiB/17.12 MiB
# wandb      ------------------------------ 5.43 MiB/21.79 MiB
# pyarrow    ------------------------------ 5.49 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠼ Preparing packages... (14/21)
# sentry-sdk ------------------------------ 368.00 KiB/415.00 KiB
# beartype   ------------------------------ 494.84 KiB/722.40 KiB
# numpy      ------------------------------ 617.81 KiB/17.12 MiB
# wandb      ------------------------------ 6.64 MiB/21.79 MiB
# pyarrow    ------------------------------ 6.51 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠼ Preparing packages... (14/21)
# sentry-sdk ------------------------------ 368.00 KiB/415.00 KiB
# beartype   ------------------------------ 510.84 KiB/722.40 KiB
# numpy      ------------------------------ 617.81 KiB/17.12 MiB
# wandb      ------------------------------ 7.24 MiB/21.79 MiB
# pyarrow    ------------------------------ 7.12 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠼ Preparing packages... (14/21)
# sentry-sdk ------------------------------ 368.00 KiB/415.00 KiB
# beartype   ------------------------------ 510.84 KiB/722.40 KiB
# numpy      ------------------------------ 617.81 KiB/17.12 MiB
# wandb      ------------------------------ 8.39 MiB/21.79 MiB
# pyarrow    ------------------------------ 7.80 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠴ Preparing packages... (14/21)
# sentry-sdk ------------------------------ 368.00 KiB/415.00 KiB
# beartype   ------------------------------ 510.84 KiB/722.40 KiB
# numpy      ------------------------------ 617.81 KiB/17.12 MiB
# wandb      ------------------------------ 9.02 MiB/21.79 MiB
# pyarrow    ------------------------------ 9.12 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠴ Preparing packages... (14/21)
# sentry-sdk ------------------------------ 368.00 KiB/415.00 KiB
# beartype   ------------------------------ 526.84 KiB/722.40 KiB
# numpy      ------------------------------ 617.81 KiB/17.12 MiB
# wandb      ------------------------------ 9.49 MiB/21.79 MiB
# pyarrow    ------------------------------ 10.09 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠴ Preparing packages... (14/21)
# sentry-sdk ------------------------------ 384.00 KiB/415.00 KiB
# beartype   ------------------------------ 526.84 KiB/722.40 KiB
# numpy      ------------------------------ 617.81 KiB/17.12 MiB
# wandb      ------------------------------ 10.68 MiB/21.79 MiB
# pyarrow    ------------------------------ 10.80 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠦ Preparing packages... (14/21)
# sentry-sdk ------------------------------ 384.00 KiB/415.00 KiB
# beartype   ------------------------------ 526.84 KiB/722.40 KiB
# numpy      ------------------------------ 617.81 KiB/17.12 MiB
# wandb      ------------------------------ 11.71 MiB/21.79 MiB
# pyarrow    ------------------------------ 11.78 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠦ Preparing packages... (14/21)
# sentry-sdk ------------------------------ 400.00 KiB/415.00 KiB
# beartype   ------------------------------ 542.95 KiB/722.40 KiB
# numpy      ------------------------------ 617.81 KiB/17.12 MiB
# wandb      ------------------------------ 12.12 MiB/21.79 MiB
# pyarrow    ------------------------------ 12.45 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠦ Preparing packages... (14/21)
# sentry-sdk ------------------------------ 400.00 KiB/415.00 KiB
# beartype   ------------------------------ 542.95 KiB/722.40 KiB
# numpy      ------------------------------ 617.81 KiB/17.12 MiB
# wandb      ------------------------------ 13.65 MiB/21.79 MiB
# pyarrow    ------------------------------ 13.11 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠦ Preparing packages... (14/21)
# sentry-sdk ------------------------------ 400.00 KiB/415.00 KiB
# beartype   ------------------------------ 558.49 KiB/722.40 KiB
# numpy      ------------------------------ 617.81 KiB/17.12 MiB
# wandb      ------------------------------ 14.03 MiB/21.79 MiB
# pyarrow    ------------------------------ 14.56 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠦ Preparing packages... (14/21)
# beartype   ------------------------------ 558.49 KiB/722.40 KiB
# numpy      ------------------------------ 617.81 KiB/17.12 MiB
# wandb      ------------------------------ 14.86 MiB/21.79 MiB
# pyarrow    ------------------------------ 15.07 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠧ Preparing packages... (14/21)
# beartype   ------------------------------ 558.49 KiB/722.40 KiB
# numpy      ------------------------------ 617.81 KiB/17.12 MiB
# wandb      ------------------------------ 14.86 MiB/21.79 MiB
# pyarrow    ------------------------------ 15.07 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠧ Preparing packages... (14/21)
# beartype   ------------------------------ 574.49 KiB/722.40 KiB
# numpy      ------------------------------ 617.81 KiB/17.12 MiB
# wandb      ------------------------------ 16.00 MiB/21.79 MiB
# pyarrow    ------------------------------ 16.60 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠧ Preparing packages... (14/21)
# beartype   ------------------------------ 574.49 KiB/722.40 KiB
# numpy      ------------------------------ 617.81 KiB/17.12 MiB
# wandb      ------------------------------ 16.93 MiB/21.79 MiB
# pyarrow    ------------------------------ 18.00 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠧ Preparing packages... (14/21)
# beartype   ------------------------------ 590.39 KiB/722.40 KiB
# numpy      ------------------------------ 633.81 KiB/17.12 MiB
# wandb      ------------------------------ 17.91 MiB/21.79 MiB
# pyarrow    ------------------------------ 18.80 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠇ Preparing packages... (15/21)
# beartype   ------------------------------ 590.39 KiB/722.40 KiB
# numpy      ------------------------------ 633.81 KiB/17.12 MiB
# wandb      ------------------------------ 18.61 MiB/21.79 MiB
# pyarrow    ------------------------------ 19.46 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠇ Preparing packages... (15/21)
# beartype   ------------------------------ 590.39 KiB/722.40 KiB
# numpy      ------------------------------ 633.81 KiB/17.12 MiB
# wandb      ------------------------------ 19.16 MiB/21.79 MiB
# pyarrow    ------------------------------ 20.29 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠇ Preparing packages... (15/21)
# beartype   ------------------------------ 590.39 KiB/722.40 KiB
# numpy      ------------------------------ 633.81 KiB/17.12 MiB
# wandb      ------------------------------ 19.71 MiB/21.79 MiB
# pyarrow    ------------------------------ 21.42 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠇ Preparing packages... (15/21)
# beartype   ------------------------------ 606.95 KiB/722.40 KiB
# numpy      ------------------------------ 633.81 KiB/17.12 MiB
# wandb      ------------------------------ 19.84 MiB/21.79 MiB
# pyarrow    ------------------------------ 22.68 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠇ Preparing packages... (15/21)
# beartype   ------------------------------ 638.95 KiB/722.40 KiB
# numpy      ------------------------------ 649.81 KiB/17.12 MiB
# wandb      ------------------------------ 19.85 MiB/21.79 MiB
# pyarrow    ------------------------------ 23.84 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠋ Preparing packages... (15/21)
# beartype   ------------------------------ 670.95 KiB/722.40 KiB
# numpy      ------------------------------ 649.81 KiB/17.12 MiB
# wandb      ------------------------------ 19.87 MiB/21.79 MiB
# pyarrow    ------------------------------ 25.16 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠋ Preparing packages... (15/21)
# beartype   ------------------------------ 686.95 KiB/722.40 KiB
# numpy      ------------------------------ 665.81 KiB/17.12 MiB
# wandb      ------------------------------ 19.87 MiB/21.79 MiB
# pyarrow    ------------------------------ 26.36 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠋ Preparing packages... (15/21)
# beartype   ------------------------------ 722.40 KiB/722.40 KiB
# numpy      ------------------------------ 665.81 KiB/17.12 MiB
# wandb      ------------------------------ 19.88 MiB/21.79 MiB
# pyarrow    ------------------------------ 27.78 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠋ Preparing packages... (15/21)
# numpy      ------------------------------ 665.81 KiB/17.12 MiB
# wandb      ------------------------------ 19.88 MiB/21.79 MiB
# pyarrow    ------------------------------ 27.78 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠙ Preparing packages... (16/21)
# numpy      ------------------------------ 665.81 KiB/17.12 MiB
# wandb      ------------------------------ 19.89 MiB/21.79 MiB
# pyarrow    ------------------------------ 29.18 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠙ Preparing packages... (16/21)
# numpy      ------------------------------ 676.04 KiB/17.12 MiB
# wandb      ------------------------------ 19.91 MiB/21.79 MiB
# pyarrow    ------------------------------ 30.65 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠙ Preparing packages... (16/21)
# numpy      ------------------------------ 692.04 KiB/17.12 MiB
# wandb      ------------------------------ 19.92 MiB/21.79 MiB
# pyarrow    ------------------------------ 31.93 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠙ Preparing packages... (16/21)
# numpy      ------------------------------ 692.04 KiB/17.12 MiB
# wandb      ------------------------------ 19.93 MiB/21.79 MiB
# pyarrow    ------------------------------ 33.12 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠹ Preparing packages... (16/21)
# numpy      ------------------------------ 692.04 KiB/17.12 MiB
# wandb      ------------------------------ 19.95 MiB/21.79 MiB
# pyarrow    ------------------------------ 34.59 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠹ Preparing packages... (16/21)
# numpy      ------------------------------ 713.81 KiB/17.12 MiB
# wandb      ------------------------------ 19.95 MiB/21.79 MiB
# pyarrow    ------------------------------ 35.71 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠹ Preparing packages... (16/21)
# numpy      ------------------------------ 761.81 KiB/17.12 MiB
# wandb      ------------------------------ 19.95 MiB/21.79 MiB
# pyarrow    ------------------------------ 36.93 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠹ Preparing packages... (16/21)
# numpy      ------------------------------ 811.20 KiB/17.12 MiB
# wandb      ------------------------------ 19.96 MiB/21.79 MiB
# pyarrow    ------------------------------ 38.03 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠹ Preparing packages... (16/21)
# numpy      ------------------------------ 836.81 KiB/17.12 MiB
# wandb      ------------------------------ 19.98 MiB/21.79 MiB
# pyarrow    ------------------------------ 39.43 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠸ Preparing packages... (16/21)
# numpy      ------------------------------ 836.81 KiB/17.12 MiB
# wandb      ------------------------------ 19.98 MiB/21.79 MiB
# pyarrow    ------------------------------ 40.91 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠸ Preparing packages... (16/21)
# numpy      ------------------------------ 852.81 KiB/17.12 MiB
# wandb      ------------------------------ 20.00 MiB/21.79 MiB
# pyarrow    ------------------------------ 42.31 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠸ Preparing packages... (16/21)
# numpy      ------------------------------ 852.81 KiB/17.12 MiB
# wandb      ------------------------------ 20.00 MiB/21.79 MiB
# pyarrow    ------------------------------ 43.30 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠸ Preparing packages... (16/21)
# numpy      ------------------------------ 996.81 KiB/17.12 MiB
# wandb      ------------------------------ 20.07 MiB/21.79 MiB
# pyarrow    ------------------------------ 43.50 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠼ Preparing packages... (16/21)
# numpy      ------------------------------ 1.00 MiB/17.12 MiB
# wandb      ------------------------------ 20.25 MiB/21.79 MiB
# pyarrow    ------------------------------ 43.64 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠼ Preparing packages... (16/21)
# numpy      ------------------------------ 1.00 MiB/17.12 MiB
# wandb      ------------------------------ 20.25 MiB/21.79 MiB
# pyarrow    ------------------------------ 43.64 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠼ Preparing packages... (16/21)
# numpy      ------------------------------ 1.00 MiB/17.12 MiB
# wandb      ------------------------------ 20.25 MiB/21.79 MiB
# pyarrow    ------------------------------ 43.64 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠼ Preparing packages... (16/21)
# numpy      ------------------------------ 1.05 MiB/17.12 MiB
# wandb      ------------------------------ 20.28 MiB/21.79 MiB
# pyarrow    ------------------------------ 43.75 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠴ Preparing packages... (16/21)
# numpy      ------------------------------ 1.61 MiB/17.12 MiB
# wandb      ------------------------------ 20.37 MiB/21.79 MiB
# pyarrow    ------------------------------ 43.82 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠴ Preparing packages... (16/21)
# numpy      ------------------------------ 2.11 MiB/17.12 MiB
# wandb      ------------------------------ 20.42 MiB/21.79 MiB
# pyarrow    ------------------------------ 43.87 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠴ Preparing packages... (16/21)
# numpy      ------------------------------ 2.40 MiB/17.12 MiB
# wandb      ------------------------------ 20.50 MiB/21.79 MiB
# pyarrow    ------------------------------ 43.92 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠦ Preparing packages... (16/21)
# numpy      ------------------------------ 4.44 MiB/17.12 MiB
# wandb      ------------------------------ 20.54 MiB/21.79 MiB
# pyarrow    ------------------------------ 43.93 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠦ Preparing packages... (16/21)
# numpy      ------------------------------ 4.70 MiB/17.12 MiB
# wandb      ------------------------------ 20.55 MiB/21.79 MiB
# pyarrow    ------------------------------ 43.95 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠦ Preparing packages... (16/21)
# numpy      ------------------------------ 5.50 MiB/17.12 MiB
# wandb      ------------------------------ 20.63 MiB/21.79 MiB
# pyarrow    ------------------------------ 44.04 MiB/45.35 MiB
# Building transformers-stream-generator==0.0.5
# ⠦ Preparing packages... (16/21)
# numpy      ------------------------------ 5.58 MiB/17.12 MiB
# wandb      ------------------------------ 20.68 MiB/21.79 MiB
# Building transformers-stream-generator==0.0.5
# ⠦ Preparing packages... (16/21)
# numpy      ------------------------------ 5.77 MiB/17.12 MiB
# wandb      ------------------------------ 20.71 MiB/21.79 MiB
# Building transformers-stream-generator==0.0.5
# ⠧ Preparing packages... (17/21)
# numpy      ------------------------------ 6.34 MiB/17.12 MiB
# wandb      ------------------------------ 20.77 MiB/21.79 MiB
# Building transformers-stream-generator==0.0.5
# ⠧ Preparing packages... (17/21)
# numpy      ------------------------------ 8.59 MiB/17.12 MiB
# wandb      ------------------------------ 20.80 MiB/21.79 MiB
# Building transformers-stream-generator==0.0.5
# ⠧ Preparing packages... (17/21)
# numpy      ------------------------------ 10.59 MiB/17.12 MiB
# wandb      ------------------------------ 20.80 MiB/21.79 MiB
# Building transformers-stream-generator==0.0.5
# ⠧ Preparing packages... (17/21)
# numpy      ------------------------------ 13.64 MiB/17.12 MiB
# wandb      ------------------------------ 20.80 MiB/21.79 MiB
# Building transformers-stream-generator==0.0.5
# ⠇ Preparing packages... (17/21)
# numpy      ------------------------------ 15.99 MiB/17.12 MiB
# wandb      ------------------------------ 20.82 MiB/21.79 MiB
# Building transformers-stream-generator==0.0.5
# ⠇ Preparing packages... (17/21)
# wandb      ------------------------------ 20.87 MiB/21.79 MiB
# Building transformers-stream-generator==0.0.5
# ⠇ Preparing packages... (17/21)
# wandb      ------------------------------ 21.12 MiB/21.79 MiB
# Building transformers-stream-generator==0.0.5
# ⠇ Preparing packages... (17/21)
# wandb      ------------------------------ 21.57 MiB/21.79 MiB
# Building transformers-stream-generator==0.0.5
# ⠇ Preparing packages... (17/21)
# Building transformers-stream-generator==0.0.5
# Building transformers-stream-generator==0.0.5
#    Built transformers-stream-generator==0.0.5
# Prepared 21 packages in 3.47s
# Uninstalled 1 package in 171ms
# Installed 21 packages in 338ms
#  + beartype==0.14.1
#  + better-abc==0.0.3
#  + bitsandbytes==0.49.1
#  + datasets==4.5.0
#  + dill==0.4.0
#  + einops==0.8.1
#  + fancy-einsum==0.0.3
#  + gitdb==4.0.12
#  + gitpython==3.1.46
#  + jaxtyping==0.3.5
#  + multiprocess==0.70.18
#  - numpy==2.1.2
#  + numpy==1.26.4
#  + pyarrow==23.0.0
#  + sentry-sdk==2.50.0
#  + smmap==5.0.2
#  + transformer-lens==2.17.0
#  + transformers-stream-generator==0.0.5
#  + typeguard==4.4.2
#  + wadler-lindig==0.1.7
#  + wandb==0.24.0
#  + xxhash==3.6.0
# Note: you may need to restart the kernel to use updated packages.
#
# ====================================================================================================
# FINAL SENTINEL FLIGHT CHECK + LLAMA-3 SWAP – 4-BIT NF4 QUANT
# Model: NousResearch/Meta-Llama-3-8B-Instruct (public, no gate, tl official)
# • 4-bit quant – ~4-6 GB VRAM (home computer proof)
# • Activation shape shown
# ====================================================================================================
#
# Device: cuda
# GPU 0: NVIDIA A100-SXM4-40GB
# VRAM 0: 42.4 GB
#
# STEP 1: Loading tokenizer...
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File /usr/local/lib/python3.12/site-packages/huggingface_hub/utils/_http.py:409, in hf_raise_for_status(response, endpoint_name)
#     408 try:
# --> 409     response.raise_for_status()
#     410 except HTTPError as e:
#
# File /usr/local/lib/python3.12/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://huggingface.co/meta-llama/Llama-3-7b/resolve/main/tokenizer_config.json
#
# The above exception was the direct cause of the following exception:
#
# RepositoryNotFoundError                   Traceback (most recent call last)
# File /usr/local/lib/python3.12/site-packages/transformers/utils/hub.py:478, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     476 if len(full_filenames) == 1:
#     477     # This is slightly better for only 1 file
# --> 478     hf_hub_download(
#     479         path_or_repo_id,
#     480         filenames[0],
#     481         subfolder=None if len(subfolder) == 0 else subfolder,
#     482         repo_type=repo_type,
#     483         revision=revision,
#     484         cache_dir=cache_dir,
#     485         user_agent=user_agent,
#     486         force_download=force_download,
#     487         proxies=proxies,
#     488         resume_download=resume_download,
#     489         token=token,
#     490         local_files_only=local_files_only,
#     491     )
#     492 else:
#
# File /usr/local/lib/python3.12/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File /usr/local/lib/python3.12/site-packages/huggingface_hub/file_download.py:1010, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, proxies, etag_timeout, token, local_files_only, headers, endpoint, resume_download, force_filename, local_dir_use_symlinks)
#    1009 else:
# -> 1010     return _hf_hub_download_to_cache_dir(
#    1011         # Destination
#    1012         cache_dir=cache_dir,
#    1013         # File info
#    1014         repo_id=repo_id,
#    1015         filename=filename,
#    1016         repo_type=repo_type,
#    1017         revision=revision,
#    1018         # HTTP info
#    1019         endpoint=endpoint,
#    1020         etag_timeout=etag_timeout,
#    1021         headers=hf_headers,
#    1022         proxies=proxies,
#    1023         token=token,
#    1024         # Additional options
#    1025         local_files_only=local_files_only,
#    1026         force_download=force_download,
#    1027     )
#
# File /usr/local/lib/python3.12/site-packages/huggingface_hub/file_download.py:1117, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, proxies, token, local_files_only, force_download)
#    1116     # Otherwise, raise appropriate error
# -> 1117     _raise_on_head_call_error(head_call_error, force_download, local_files_only)
#    1119 # From now on, etag, commit_hash, url and size are not None.
#
# File /usr/local/lib/python3.12/site-packages/huggingface_hub/file_download.py:1658, in _raise_on_head_call_error(head_call_error, force_download, local_files_only)
#    1653 elif isinstance(head_call_error, (RepositoryNotFoundError, GatedRepoError)) or (
#    1654     isinstance(head_call_error, HfHubHTTPError) and head_call_error.response.status_code == 401
#    1655 ):
#    1656     # Repo not found or gated => let's raise the actual error
#    1657     # Unauthorized => likely a token issue => let's raise the actual error
# -> 1658     raise head_call_error
#    1659 else:
#    1660     # Otherwise: most likely a connection issue or Hub downtime => let's warn the user
#
# File /usr/local/lib/python3.12/site-packages/huggingface_hub/file_download.py:1546, in _get_metadata_or_catch_error(repo_id, filename, repo_type, revision, endpoint, proxies, etag_timeout, headers, token, local_files_only, relative_filename, storage_folder)
#    1545 try:
# -> 1546     metadata = get_hf_file_metadata(
#    1547         url=url, proxies=proxies, timeout=etag_timeout, headers=headers, token=token, endpoint=endpoint
#    1548     )
#    1549 except EntryNotFoundError as http_error:
#
# File /usr/local/lib/python3.12/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File /usr/local/lib/python3.12/site-packages/huggingface_hub/file_download.py:1463, in get_hf_file_metadata(url, token, proxies, timeout, library_name, library_version, user_agent, headers, endpoint)
#    1462 # Retrieve metadata
# -> 1463 r = _request_wrapper(
#    1464     method="HEAD",
#    1465     url=url,
#    1466     headers=hf_headers,
#    1467     allow_redirects=False,
#    1468     follow_relative_redirects=True,
#    1469     proxies=proxies,
#    1470     timeout=timeout,
#    1471 )
#    1472 hf_raise_for_status(r)
#
# File /usr/local/lib/python3.12/site-packages/huggingface_hub/file_download.py:286, in _request_wrapper(method, url, follow_relative_redirects, **params)
#     285 if follow_relative_redirects:
# --> 286     response = _request_wrapper(
#     287         method=method,
#     288         url=url,
#     289         follow_relative_redirects=False,
#     290         **params,
#     291     )
#     293     # If redirection, we redirect only relative paths.
#     294     # This is useful in case of a renamed repository.
#
# File /usr/local/lib/python3.12/site-packages/huggingface_hub/file_download.py:310, in _request_wrapper(method, url, follow_relative_redirects, **params)
#     309 response = http_backoff(method=method, url=url, **params, retry_on_exceptions=(), retry_on_status_codes=(429,))
# --> 310 hf_raise_for_status(response)
#     311 return response
#
# File /usr/local/lib/python3.12/site-packages/huggingface_hub/utils/_http.py:459, in hf_raise_for_status(response, endpoint_name)
#     450     message = (
#     451         f"{response.status_code} Client Error."
#     452         + "\n\n"
#    (...)    457         " https://huggingface.co/docs/huggingface_hub/authentication"
#     458     )
# --> 459     raise _format(RepositoryNotFoundError, message, response) from e
#     461 elif response.status_code == 400:
#
# RepositoryNotFoundError: 404 Client Error. (Request ID: Root=1-69749351-18c4bfc014437cb36ae8aedd;d7ac18b9-b7b1-4804-8e4b-e81ea2a3da70)
#
# Repository Not Found for url: https://huggingface.co/meta-llama/Llama-3-7b/resolve/main/tokenizer_config.json.
# Please make sure you specified the correct `repo_id` and `repo_type`.
# If you are trying to access a private or gated repo, make sure you are authenticated. For more details, see https://huggingface.co/docs/huggingface_hub/authentication
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 29
#      27 print("\nSTEP 1: Loading tokenizer...")
#      28 model_name = "meta-llama/Llama-3-7b"
# ---> 29 tokenizer = AutoTokenizer.from_pretrained(model_name)
#      30 print("Tokenizer loaded ✓")
#      32 print("\nSTEP 2: Loading base model in 4-bit NF4 quant...")
#
# File /usr/local/lib/python3.12/site-packages/transformers/models/auto/tokenization_auto.py:1058, in AutoTokenizer.from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#    1055     return tokenizer_class.from_pretrained(pretrained_model_name_or_path, *inputs, **kwargs)
#    1057 # Next, let's try to use the tokenizer_config file to get the tokenizer class.
# -> 1058 tokenizer_config = get_tokenizer_config(pretrained_model_name_or_path, **kwargs)
#    1059 if "_commit_hash" in tokenizer_config:
#    1060     kwargs["_commit_hash"] = tokenizer_config["_commit_hash"]
#
# File /usr/local/lib/python3.12/site-packages/transformers/models/auto/tokenization_auto.py:890, in get_tokenizer_config(pretrained_model_name_or_path, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, **kwargs)
#     887     token = use_auth_token
#     889 commit_hash = kwargs.get("_commit_hash")
# --> 890 resolved_config_file = cached_file(
#     891     pretrained_model_name_or_path,
#     892     TOKENIZER_CONFIG_FILE,
#     893     cache_dir=cache_dir,
#     894     force_download=force_download,
#     895     resume_download=resume_download,
#     896     proxies=proxies,
#     897     token=token,
#     898     revision=revision,
#     899     local_files_only=local_files_only,
#     900     subfolder=subfolder,
#     901     _raise_exceptions_for_gated_repo=False,
#     902     _raise_exceptions_for_missing_entries=False,
#     903     _raise_exceptions_for_connection_errors=False,
#     904     _commit_hash=commit_hash,
#     905 )
#     906 if resolved_config_file is None:
#     907     logger.info("Could not locate the tokenizer configuration file, will try to use the model config instead.")
#
# File /usr/local/lib/python3.12/site-packages/transformers/utils/hub.py:321, in cached_file(path_or_repo_id, filename, **kwargs)
#     263 def cached_file(
#     264     path_or_repo_id: Union[str, os.PathLike],
#     265     filename: str,
#     266     **kwargs,
#     267 ) -> Optional[str]:
#     268     """
#     269     Tries to locate a file in a local folder and repo, downloads and cache it if necessary.
#     270
#    (...)    319     ```
#     320     """
# --> 321     file = cached_files(path_or_repo_id=path_or_repo_id, filenames=[filename], **kwargs)
#     322     file = file[0] if file is not None else file
#     323     return file
#
# File /usr/local/lib/python3.12/site-packages/transformers/utils/hub.py:510, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     507 except Exception as e:
#     508     # We cannot recover from them
#     509     if isinstance(e, RepositoryNotFoundError) and not isinstance(e, GatedRepoError):
# --> 510         raise OSError(
#     511             f"{path_or_repo_id} is not a local folder and is not a valid model identifier "
#     512             "listed on 'https://huggingface.co/models'\nIf this is a private repository, make sure to pass a token "
#     513             "having permission to this repo either by logging in with `hf auth login` or by passing "
#     514             "`token=<your_token>`"
#     515         ) from e
#     516     elif isinstance(e, RevisionNotFoundError):
#     517         raise OSError(
#     518             f"{revision} is not a valid git identifier (branch name, tag name or commit id) that exists "
#     519             "for this model name. Check the model page at "
#     520             f"'https://huggingface.co/{path_or_repo_id}' for available revisions."
#     521         ) from e
#
# OSError: meta-llama/Llama-3-7b is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
